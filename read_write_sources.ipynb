# %%
import pandas as pd

# %%
na_vals = ['NA', 'Missing']
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent', na_values=na_vals)
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
# 3                               Employed full-time                Thailand
# 4                               Employed full-time           United States
# 5                               Employed full-time                 Ukraine
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# 2           Yes, full-time  Secondary school (e.g. American high school, G...
# 3                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 3           Taught yourself a new language, framework, or ...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
#
#                              OrgSize  \
# Respondent
# 1                                NaN
# 2                                NaN
# 3               100 to 499 employees
# 4               100 to 499 employees
# 5           10,000 or more employees
#
#                                                       DevType YearsCode  \
# Respondent
# 1                                                         NaN         4
# 2           Developer, desktop or enterprise applications;...       NaN
# 3           Designer;Developer, back-end;Developer, front-...         3
# 4                                       Developer, full-stack         3
# 5           Academic researcher;Developer, desktop or ente...        16
#
#            Age1stCode      YearsCodePro           CareerSat  \
# Respondent
# 1                  10               NaN                 NaN
# 2                  17               NaN                 NaN
# 3                  22                 1  Slightly satisfied
# 4                  16  Less than 1 year      Very satisfied
# 5                  14                 9   Very dissatisfied
#
#                            JobSat              MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 1                             NaN                   NaN       NaN       NaN
# 2                             NaN                   NaN       NaN       NaN
# 3              Slightly satisfied  Not at all confident  Not sure  Not sure
# 4              Slightly satisfied        Very confident        No  Not sure
# 5           Slightly dissatisfied    Somewhat confident       Yes        No
#
#                                                       JobSeek  \
# Respondent
# 1                                                         NaN
# 2                             I am actively looking for a job
# 3           I’m not actively looking, but I am open to new...
# 4                I am not interested in new job opportunities
# 5                I am not interested in new job opportunities
#
#                     LastHireDate  \
# Respondent
# 1                            NaN
# 2           I've never had a job
# 3                  1-2 years ago
# 4           Less than a year ago
# 5           Less than a year ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 1                                                         NaN      NaN
# 2                                                         NaN      NaN
# 3                         Interview with people in peer roles       No
# 4           Write code by hand (e.g., on a whiteboard);Int...       No
# 5           Write any code;Write code by hand (e.g., on a ...       No
#
#                                                    JobFactors  \
# Respondent
# 1                                                         NaN
# 2           Financial performance or funding status of the...
# 3           Languages, frameworks, and other technologies ...
# 4           Languages, frameworks, and other technologies ...
# 5           Industry that I'd be working in;Languages, fra...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 1                                                         NaN            NaN
# 2           Something else changed (education, award, medi...            NaN
# 3                            I was preparing for a job search            THB
# 4                            I was preparing for a job search            USD
# 5                            I was preparing for a job search            UAH
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 1                            NaN        NaN      NaN            NaN
# 2                            NaN        NaN      NaN            NaN
# 3                      Thai baht    23000.0  Monthly         8820.0
# 4           United States dollar    61000.0   Yearly        61000.0
# 5              Ukrainian hryvnia        NaN      NaN            NaN
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                  40.0  There's no schedule or spec; I work on what se...
# 4                  80.0  There's no schedule or spec; I work on what se...
# 5                  55.0  There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3           Distracting work environment;Inadequate access...
# 4                                                         NaN
# 5           Being tasked with non-development work;Inadequ...
#
#                                   WorkRemote WorkLoc                  ImpSyn  \
# Respondent
# 1                                        NaN     NaN                     NaN
# 2                                        NaN     NaN                     NaN
# 3           Less than once per month / Never    Home                 Average
# 4           Less than once per month / Never    Home  A little below average
# 5                      A few days each month  Office  A little above average
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 1                                               NaN         NaN
# 2                                               NaN         NaN
# 3                                                No         NaN
# 4                                                No         NaN
# 5           Yes, because I see value in code review         NaN
#
#                                 UnitTests  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3               No, but I think we should
# 4               No, but I think we should
# 5           Yes, it's part of our process
#
#                                                   PurchaseHow  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                    Not sure
# 4           Developers typically have the most influence o...
# 5                                                    Not sure
#
#                              PurchaseWhat  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3           I have little or no influence
# 4           I have little or no influence
# 5           I have little or no influence
#
#                                      LanguageWorkedWith  \
# Respondent
# 1                       HTML/CSS;Java;JavaScript;Python
# 2                                   C++;HTML/CSS;Python
# 3                                              HTML/CSS
# 4                                   C;C++;C#;Python;SQL
# 5           C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#
#                                      LanguageDesireNextYear  \
# Respondent
# 1           C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 2                               C++;HTML/CSS;JavaScript;SQL
# 3                                           Elixir;HTML/CSS
# 4                                       C;C#;JavaScript;SQL
# 5                  HTML/CSS;Java;JavaScript;SQL;WebAssembly
#
#                                           DatabaseWorkedWith  \
# Respondent
# 1                                                     SQLite
# 2                                                        NaN
# 3                                                 PostgreSQL
# 4                                               MySQL;SQLite
# 5           Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1                                                       MySQL
# 2                                                       MySQL
# 3                                                  PostgreSQL
# 4                                                MySQL;SQLite
# 5           Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
#
#                            PlatformWorkedWith  \
# Respondent
# 1                               MacOS;Windows
# 2                                     Windows
# 3                                         NaN
# 4                               Linux;Windows
# 5           Android;Linux;MacOS;Slack;Windows
#
#                            PlatformDesireNextYear  \
# Respondent
# 1                         Android;Arduino;Windows
# 2                                         Windows
# 3                                             NaN
# 4                                   Linux;Windows
# 5           Android;Docker;Kubernetes;Linux;Slack
#
#                                      WebFrameWorkedWith  \
# Respondent
# 1                                          Django;Flask
# 2                                                Django
# 3                                                   NaN
# 4                                                   NaN
# 5           Django;Express;Flask;jQuery;React.js;Spring
#
#                   WebFrameDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                           Flask;jQuery            Node.js
# 2                                 Django                NaN
# 3                              Other(s):                NaN
# 4                                    NaN               .NET
# 5           Flask;jQuery;React.js;Spring    Cordova;Node.js
#
#                               MiscTechDesireNextYear  \
# Respondent
# 1                                            Node.js
# 2                                                NaN
# 3                                                NaN
# 4                                               .NET
# 5           Apache Spark;Hadoop;Node.js;React Native
#
#                                               DevEnviron        OpSys  \
# Respondent
# 1                             IntelliJ;Notepad++;PyCharm      Windows
# 2                                           Atom;PyCharm      Windows
# 3                                 Vim;Visual Studio Code  Linux-based
# 4           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 5                                 IntelliJ;Notepad++;Vim  Linux-based
#
#                                         Containers BlockchainOrg  \
# Respondent
# 1                          I do not use containers           NaN
# 2                          I do not use containers           NaN
# 3                          I do not use containers           NaN
# 4                          I do not use containers    Not at all
# 5           Outside of work, for personal projects    Not at all
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 1                                                         NaN        Yes
# 2           Useful across many domains and could change ma...        Yes
# 3                                                         NaN        Yes
# 4           Useful for decentralized currency (i.e., Bitcoin)        Yes
# 5                                                         NaN        Yes
#
#                                             ITperson OffOn SocialMedia  \
# Respondent
# 1           Fortunately, someone else has that title   Yes     Twitter
# 2                                                Yes   Yes   Instagram
# 3                                                Yes   Yes      Reddit
# 4                                               SIGH   Yes      Reddit
# 5                                           Also Yes   Yes    Facebook
#
#                         Extraversion ScreenName        SOVisit1st  \
# Respondent
# 1                             Online   Username              2017
# 2                             Online   Username              2017
# 3           In real life (in person)   Username              2011
# 4           In real life (in person)   Username              2014
# 5           In real life (in person)   Username  I don't remember
#
#                                 SOVisitFreq  \
# Respondent
# 1           A few times per month or weekly
# 2                     Daily or almost daily
# 3                      A few times per week
# 4                     Daily or almost daily
# 5                    Multiple times per day
#
#                                                     SOVisitTo  \
# Respondent
# 1           Find answers to specific questions;Learn how t...
# 2           Find answers to specific questions;Learn how t...
# 3           Find answers to specific questions;Learn how t...
# 4           Find answers to specific questions;Pass the ti...
# 5                          Find answers to specific questions
#
#                            SOFindAnswer                     SOTimeSaved  \
# Respondent
# 1                    3-5 times per week  Stack Overflow was much faster
# 2                    3-5 times per week  Stack Overflow was much faster
# 3                   6-10 times per week        They were about the same
# 4                    1-2 times per week  Stack Overflow was much faster
# 5           More than 10 times per week  Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount                           SOPartFreq  \
# Respondent
# 1           31-60 minutes        No                                  NaN
# 2           11-30 minutes       Yes      A few times per month or weekly
# 3                     NaN       Yes  Less than once per month or monthly
# 4           31-60 minutes       Yes  Less than once per month or monthly
# 5                     NaN       Yes      A few times per month or weekly
#
#                                                        SOJobs  \
# Respondent
# 1           No, I didn't know that Stack Overflow had a jo...
# 2           No, I knew that Stack Overflow had a job board...
# 3                                                         Yes
# 4                                                         Yes
# 5           No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 1                         No, and I don't know what those are
# 2                         No, and I don't know what those are
# 3           No, I've heard of them, but I am not part of a...
# 4                         No, and I don't know what those are
# 5           No, I've heard of them, but I am not part of a...
#
#                      SOComm                            WelcomeChange  \
# Respondent
# 1                   Neutral  Just as welcome now as I felt last year
# 2             Yes, somewhat  Just as welcome now as I felt last year
# 3                   Neutral  Just as welcome now as I felt last year
# 4            No, not really  Just as welcome now as I felt last year
# 5           Yes, definitely  Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 1           Tech articles written by other developers;Indu...  14.0    Man
# 2           Tech articles written by other developers;Indu...  19.0    Man
# 3           Tech meetups or events in your area;Courses on...  28.0    Man
# 4           Tech articles written by other developers;Indu...  22.0    Man
# 5           Tech meetups or events in your area;Courses on...  30.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 1             No  Straight / Heterosexual
# 2             No  Straight / Heterosexual
# 3             No  Straight / Heterosexual
# 4             No  Straight / Heterosexual
# 5             No  Straight / Heterosexual
#
#                                            Ethnicity Dependents  \
# Respondent
# 1                                                NaN         No
# 2                                                NaN         No
# 3                                                NaN        Yes
# 4                       White or of European descent         No
# 5           White or of European descent;Multiracial         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy

# %%
filt = (df['Country']) == 'India'
india_df = df[filt]
india_df
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# 15                                                      Never
# 50                                 Once a month or more often
# 65                                                      Never
# ...                                                       ...
# 77339                                 Less than once per year
# 79795       Less than once a month but more than once per ...
# 83862                              Once a month or more often
# 84299                                                   Never
# 86012                              Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# 65                                                        NaN
# ...                                                       ...
# 77339       OSS is, on average, of HIGHER quality than pro...
# 79795       OSS is, on average, of HIGHER quality than pro...
# 83862       OSS is, on average, of HIGHER quality than pro...
# 84299       The quality of OSS and closed source software ...
# 86012       OSS is, on average, of HIGHER quality than pro...
#
#                                     Employment Country         Student  \
# Respondent
# 8           Not employed, but looking for work   India             NaN
# 10                          Employed full-time   India              No
# 15          Not employed, but looking for work   India  Yes, full-time
# 50                          Employed full-time   India              No
# 65                          Employed full-time   India              No
# ...                                        ...     ...             ...
# 77339                       Employed full-time   India  Yes, full-time
# 79795                       Employed full-time   India              No
# 83862                       Employed full-time   India  Yes, full-time
# 84299                       Employed full-time   India  Yes, full-time
# 86012                       Employed full-time   India              No
#
#                                                       EdLevel  \
# Respondent
# 8                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 10                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 15          Secondary school (e.g. American high school, G...
# 50                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 65                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                       ...
# 77339                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 79795                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 83862                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 84299                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 86012             Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                                UndergradMajor  \
# Respondent
# 8           Computer science, computer engineering, or sof...
# 10                                                        NaN
# 15                                                        NaN
# 50          Another engineering discipline (ex. civil, ele...
# 65          Information systems, information technology, o...
# ...                                                       ...
# 77339       Another engineering discipline (ex. civil, ele...
# 79795       Computer science, computer engineering, or sof...
# 83862                                                     NaN
# 84299                           Web development or web design
# 86012       Another engineering discipline (ex. civil, ele...
#
#                                                      EduOther  \
# Respondent
# 8           Taught yourself a new language, framework, or ...
# 10                                                        NaN
# 15          Taken an online course in programming or softw...
# 50          Received on-the-job training in software devel...
# 65                                                        NaN
# ...                                                       ...
# 77339       Taken an online course in programming or softw...
# 79795       Taken an online course in programming or softw...
# 83862                             Participated in a hackathon
# 84299       Taken an online course in programming or softw...
# 86012       Taught yourself a new language, framework, or ...
#
#                              OrgSize  \
# Respondent
# 8                                NaN
# 10          10,000 or more employees
# 15                               NaN
# 50          10,000 or more employees
# 65                20 to 99 employees
# ...                              ...
# 77339       1,000 to 4,999 employees
# 79795           500 to 999 employees
# 83862                            NaN
# 84299           100 to 499 employees
# 86012           100 to 499 employees
#
#                                                       DevType YearsCode  \
# Respondent
# 8              Developer, back-end;Engineer, site reliability         8
# 10          Data or business analyst;Data scientist or mac...        12
# 15                                                    Student         3
# 50                      Developer, back-end;DevOps specialist         7
# 65                     Developer, front-end;Developer, mobile         2
# ...                                                       ...       ...
# 77339                                                     NaN         1
# 79795                                   Developer, QA or test         6
# 83862                        Data or business analyst;Student         1
# 84299       Developer, back-end;Developer, front-end;Devel...        12
# 86012                            Academic researcher;Educator         5
#
#            Age1stCode      YearsCodePro              CareerSat  \
# Respondent
# 8                  16               NaN                    NaN
# 10                 20                10  Slightly dissatisfied
# 15                 13               NaN                    NaN
# 50                 15                 2     Slightly satisfied
# 65                 17                 2         Very satisfied
# ...               ...               ...                    ...
# 77339              27                 1                    NaN
# 79795              17                 5                    NaN
# 83862              18  Less than 1 year                    NaN
# 84299              25                12                    NaN
# 86012              15               NaN                    NaN
#
#                            JobSat            MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 8                             NaN                 NaN       NaN       NaN
# 10          Slightly dissatisfied  Somewhat confident       Yes       Yes
# 15                            NaN                 NaN       NaN       NaN
# 50                 Very satisfied      Very confident  Not sure       Yes
# 65                 Very satisfied      Very confident        No  Not sure
# ...                           ...                 ...       ...       ...
# 77339                         NaN  Somewhat confident       Yes       Yes
# 79795                         NaN  Somewhat confident        No  Not sure
# 83862                         NaN      Very confident  Not sure       Yes
# 84299                         NaN                 NaN       NaN       NaN
# 86012                         NaN  Somewhat confident        No  Not sure
#
#                                                       JobSeek  \
# Respondent
# 8                                                         NaN
# 10          I’m not actively looking, but I am open to new...
# 15          I’m not actively looking, but I am open to new...
# 50          I’m not actively looking, but I am open to new...
# 65          I’m not actively looking, but I am open to new...
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                                     NaN
# 86012                                                     NaN
#
#                     LastHireDate  \
# Respondent
# 8                            NaN
# 10                 3-4 years ago
# 15          I've never had a job
# 50                 1-2 years ago
# 65          Less than a year ago
# ...                          ...
# 77339                        NaN
# 79795                        NaN
# 83862                        NaN
# 84299                        NaN
# 86012                        NaN
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 8                                                         NaN      NaN
# 10                                                        NaN       No
# 15                                                        NaN      NaN
# 50          Write code by hand (e.g., on a whiteboard);Int...       No
# 65          Write any code;Solve a brain-teaser style puzz...       No
# ...                                                       ...      ...
# 77339                                                     NaN      NaN
# 79795                                                     NaN      NaN
# 83862                                                     NaN      NaN
# 84299                                                     NaN      NaN
# 86012                                                     NaN      NaN
#
#                                                    JobFactors  \
# Respondent
# 8                                                         NaN
# 10          Languages, frameworks, and other technologies ...
# 15          Industry that I'd be working in;Languages, fra...
# 50          Specific department or team I'd be working on;...
# 65          Languages, frameworks, and other technologies ...
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                                     NaN
# 86012                                                     NaN
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 8                                                         NaN            NaN
# 10                                                        NaN            INR
# 15          Something else changed (education, award, medi...            NaN
# 50                           I was preparing for a job search            INR
# 65           My job status changed (promotion, new job, etc.)            INR
# ...                                                       ...            ...
# 77339                                                     NaN            NaN
# 79795                                                     NaN            NaN
# 83862                                                     NaN            NaN
# 84299                                                     NaN            NaN
# 86012                                                     NaN            NaN
#
#             CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# Respondent
# 8                    NaN        NaN      NaN            NaN          NaN
# 10          Indian rupee   950000.0   Yearly        13293.0         70.0
# 15                   NaN        NaN      NaN            NaN          NaN
# 50          Indian rupee   400000.0   Yearly         5597.0          7.0
# 65          Indian rupee        NaN  Monthly            NaN         48.0
# ...                  ...        ...      ...            ...          ...
# 77339                NaN        NaN      NaN            NaN          NaN
# 79795                NaN        NaN      NaN            NaN          NaN
# 83862                NaN        NaN      NaN            NaN          NaN
# 84299                NaN        NaN      NaN            NaN          NaN
# 86012                NaN        NaN      NaN            NaN          NaN
#
#                                                      WorkPlan  \
# Respondent
# 8                                                         NaN
# 10          There's no schedule or spec; I work on what se...
# 15                                                        NaN
# 50          There is a schedule and/or spec (made by me or...
# 65          There's no schedule or spec; I work on what se...
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                                     NaN
# 86012                                                     NaN
#
#                             WorkChallenge                        WorkRemote  \
# Respondent
# 8                                     NaN                               NaN
# 10                                    NaN             A few days each month
# 15                                    NaN                               NaN
# 50          Meetings;Time spent commuting  Less than once per month / Never
# 65                                    NaN               About half the time
# ...                                   ...                               ...
# 77339                                 NaN                               NaN
# 79795                                 NaN                               NaN
# 83862                                 NaN                               NaN
# 84299                                 NaN                               NaN
# 86012                                 NaN                               NaN
#
#                                                    WorkLoc             ImpSyn  \
# Respondent
# 8                                                      NaN                NaN
# 10                                                    Home  Far above average
# 15                                                     NaN                NaN
# 50          Other place, such as a coworking space or cafe            Average
# 65                                                  Office            Average
# ...                                                    ...                ...
# 77339                                                  NaN                NaN
# 79795                                                  NaN                NaN
# 83862                                                  NaN                NaN
# 84299                                                  NaN                NaN
# 86012                                                  NaN                NaN
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 8                                               NaN         NaN
# 10          Yes, because I see value in code review         4.0
# 15                                              NaN         NaN
# 50                                               No         NaN
# 65          Yes, because I see value in code review         NaN
# ...                                             ...         ...
# 77339                                           NaN         NaN
# 79795                                           NaN         NaN
# 83862                                           NaN         NaN
# 84299                                           NaN         NaN
# 86012                                           NaN         NaN
#
#                                                     UnitTests  \
# Respondent
# 8                                                         NaN
# 10                              Yes, it's part of our process
# 15                                                        NaN
# 50          Yes, it's not part of our process but the deve...
# 65          Yes, it's not part of our process but the deve...
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                                     NaN
# 86012                                                     NaN
#
#                                                   PurchaseHow  \
# Respondent
# 8                                                         NaN
# 10                                                        NaN
# 15                                                        NaN
# 50          The CTO, CIO, or other management purchase new...
# 65                                                   Not sure
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                                     NaN
# 86012                                                     NaN
#
#                              PurchaseWhat  \
# Respondent
# 8                                     NaN
# 10                                    NaN
# 15                                    NaN
# 50          I have little or no influence
# 65                                    NaN
# ...                                   ...
# 77339                                 NaN
# 79795                                 NaN
# 83862                                 NaN
# 84299                                 NaN
# 86012                                 NaN
#
#                                            LanguageWorkedWith  \
# Respondent
# 8           Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 10                              C#;Go;JavaScript;Python;R;SQL
# 15          Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 50          Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 65                            Assembly;C;C++;C#;HTML/CSS;Java
# ...                                                       ...
# 77339                                               Other(s):
# 79795                    Bash/Shell/PowerShell;Python;SQL;VBA
# 83862       Assembly;C;C++;HTML/CSS;Java;JavaScript;Object...
# 84299        HTML/CSS;Java;JavaScript;Python;Swift;TypeScript
# 86012           Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript
#
#                                        LanguageDesireNextYear  \
# Respondent
# 8           Bash/Shell/PowerShell;C;C++;Elixir;Erlang;Go;P...
# 10                       C#;Go;JavaScript;Kotlin;Python;R;SQL
# 15          Assembly;Bash/Shell/PowerShell;C;C++;C#;Go;HTM...
# 50                                 HTML/CSS;JavaScript;Python
# 65                                                     Kotlin
# ...                                                       ...
# 77339                                              Python;SQL
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                HTML/CSS;Java;JavaScript
# 86012                                              C++;Python
#
#                                            DatabaseWorkedWith  \
# Respondent
# 8           Cassandra;Elasticsearch;MongoDB;MySQL;Oracle;R...
# 10          Elasticsearch;MongoDB;Microsoft SQL Server;MyS...
# 15                                MariaDB;MySQL;Oracle;SQLite
# 50          Elasticsearch;Firebase;MariaDB;MongoDB;MySQL;O...
# 65                               Firebase;MySQL;Oracle;SQLite
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                   MySQL
# 84299                                    MongoDB;Redis;SQLite
# 86012                                                   MySQL
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 8           Cassandra;DynamoDB;Elasticsearch;Firebase;Mong...
# 10                 Elasticsearch;MongoDB;Microsoft SQL Server
# 15          MariaDB;MongoDB;Microsoft SQL Server;MySQL;Ora...
# 50                        Firebase;PostgreSQL;Redis;Other(s):
# 65                                            Firebase;SQLite
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                          DynamoDB;Elasticsearch;MongoDB
# 84299                                           MongoDB;Redis
# 86012                                                     NaN
#
#                                            PlatformWorkedWith  \
# Respondent
# 8                         AWS;Docker;Heroku;Linux;MacOS;Slack
# 10                                              Linux;Windows
# 15                                              Linux;Windows
# 50          Arduino;AWS;Heroku;Linux;MacOS;Raspberry Pi;Wo...
# 65                                                    Android
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862             Android;AWS;Google Cloud Platform;WordPress
# 84299                                                     NaN
# 86012                                               Other(s):
#
#                                        PlatformDesireNextYear  \
# Respondent
# 8           Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 10                         Android;Linux;Raspberry Pi;Windows
# 15          Android;Google Cloud Platform;iOS;Linux;MacOS;...
# 50          AWS;Docker;Heroku;Kubernetes;Linux;MacOS;WordP...
# 65                                                    Android
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                     IBM Cloud or Watson
# 84299                                                     NaN
# 86012                                               Other(s):
#
#                                            WebFrameWorkedWith  \
# Respondent
# 8                               Express;Flask;React.js;Spring
# 10          Angular/Angular.js;ASP.NET;Django;Express;Flas...
# 15                                                        NaN
# 50                                Django;Express;Flask;jQuery
# 65                                                    ASP.NET
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                 Laravel
# 84299       Angular/Angular.js;Express;jQuery;React.js;Oth...
# 86012                                                     NaN
#
#                                        WebFrameDesireNextYear  \
# Respondent
# 8                        Django;Express;Flask;React.js;Vue.js
# 10          Angular/Angular.js;ASP.NET;Django;Express;Flas...
# 15          Angular/Angular.js;ASP.NET;Django;Drupal;jQuer...
# 50                       Express;Flask;jQuery;React.js;Vue.js
# 65                                                        NaN
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                       Angular/Angular.js;Laravel;Vue.js
# 84299                              Express;React.js;Other(s):
# 86012                                                     NaN
#
#                            MiscTechWorkedWith  \
# Respondent
# 8                       Hadoop;Node.js;Pandas
# 10          .NET;Node.js;Pandas;Torch/PyTorch
# 15                                        NaN
# 50                                    Node.js
# 65                                        NaN
# ...                                       ...
# 77339                                     NaN
# 79795                Apache Spark;Chef;Puppet
# 83862                                     NaN
# 84299                                 Node.js
# 86012                                     NaN
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 8           Ansible;Apache Spark;Chef;Hadoop;Node.js;Panda...
# 10                      .NET;Node.js;TensorFlow;Torch/PyTorch
# 15          .NET;.NET Core;Node.js;TensorFlow;Unity 3D;Unr...
# 50                                                    Node.js
# 65                                                        NaN
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                 Node.js
# 84299                                                 Node.js
# 86012                                                     NaN
#
#                                                    DevEnviron        OpSys  \
# Respondent
# 8           Atom;IntelliJ;IPython / Jupyter;PyCharm;Visual...  Linux-based
# 10          Android Studio;Eclipse;IPython / Jupyter;Notep...      Windows
# 15                   Atom;NetBeans;Notepad++;Sublime Text;Vim  Linux-based
# 50                               Notepad++;Visual Studio Code        MacOS
# 65                                    Android Studio;IntelliJ  Linux-based
# ...                                                       ...          ...
# 77339                                                     NaN  Linux-based
# 79795                                             PyCharm;Vim  Linux-based
# 83862       Android Studio;Atom;IntelliJ;Komodo;NetBeans;N...      Windows
# 84299             IntelliJ;Notepad++;Visual Studio Code;Xcode      Windows
# 86012                                               Notepad++  Linux-based
#
#                                                    Containers BlockchainOrg  \
# Respondent
# 8           Development;Testing;Production;Outside of work...           NaN
# 10                                                        NaN    Not at all
# 15                                                Development           NaN
# 50                                                    Testing    Not at all
# 65                                                        NaN           NaN
# ...                                                       ...           ...
# 77339                                 I do not use containers           NaN
# 79795       Development;Testing;Production;Outside of work...    Not at all
# 83862                                 I do not use containers           NaN
# 84299                                                     NaN           NaN
# 86012                                 I do not use containers           NaN
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 8           Useful across many domains and could change ma...        Yes
# 10          Useful for immutable record keeping outside of...         No
# 15                                                        NaN        Yes
# 50          Useful for immutable record keeping outside of...        Yes
# 65                                                        NaN        Yes
# ...                                                       ...        ...
# 77339                                                     NaN        Yes
# 79795                                                     NaN         No
# 83862       Useful across many domains and could change ma...         No
# 84299                                                     NaN        Yes
# 86012                                                     NaN         No
#
#                                             ITperson  OffOn  \
# Respondent
# 8                                               SIGH    Yes
# 10                                               Yes    Yes
# 15                                               Yes  What?
# 50                                          Also Yes  What?
# 65                                               Yes  What?
# ...                                              ...    ...
# 77339                                            Yes     No
# 79795                                            Yes  What?
# 83862                                            Yes  What?
# 84299       Fortunately, someone else has that title  What?
# 86012                                       Also Yes  What?
#
#                          SocialMedia              Extraversion   ScreenName  \
# Respondent
# 8                            YouTube  In real life (in person)       Handle
# 10                           YouTube                   Neither  Screen Name
# 15                           YouTube  In real life (in person)          NaN
# 50                           YouTube  In real life (in person)     Username
# 65                          WhatsApp  In real life (in person)          NaN
# ...                              ...                       ...          ...
# 77339                        YouTube                    Online       UserID
# 79795                      Instagram  In real life (in person)     Username
# 83862                        Twitter                    Online       UserID
# 84299                       LinkedIn                       NaN          NaN
# 86012       I don't use social media                    Online     Username
#
#            SOVisit1st                          SOVisitFreq  \
# Respondent
# 8                2012                 A few times per week
# 10                NaN               Multiple times per day
# 15               2018                Daily or almost daily
# 50               2012                Daily or almost daily
# 65               2017               Multiple times per day
# ...               ...                                  ...
# 77339            2019  Less than once per month or monthly
# 79795            2018      A few times per month or weekly
# 83862            2012      A few times per month or weekly
# 84299            2011      A few times per month or weekly
# 86012            2014      A few times per month or weekly
#
#                                                     SOVisitTo  \
# Respondent
# 8           Find answers to specific questions;Learn how t...
# 10          Find answers to specific questions;Get a sense...
# 15          Find answers to specific questions;Learn how t...
# 50          Find answers to specific questions;Learn how t...
# 65                         Find answers to specific questions
# ...                                                       ...
# 77339       Find answers to specific questions;Learn how t...
# 79795                      Find answers to specific questions
# 83862       Find answers to specific questions;Learn how t...
# 84299       Find answers to specific questions;Contribute ...
# 86012                      Find answers to specific questions
#
#                            SOFindAnswer                         SOTimeSaved  \
# Respondent
# 8               Less than once per week  Stack Overflow was slightly faster
# 10                   3-5 times per week            They were about the same
# 15          More than 10 times per week            They were about the same
# 50                   3-5 times per week  Stack Overflow was slightly faster
# 65          More than 10 times per week  Stack Overflow was slightly faster
# ...                                 ...                                 ...
# 77339                1-2 times per week      Stack Overflow was much faster
# 79795           Less than once per week            They were about the same
# 83862           Less than once per week      Stack Overflow was much faster
# 84299           Less than once per week      Stack Overflow was much faster
# 86012           Less than once per week      Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount  \
# Respondent
# 8           11-30 minutes       Yes
# 10                    NaN       Yes
# 15                    NaN       Yes
# 50          11-30 minutes       Yes
# 65          11-30 minutes       Yes
# ...                   ...       ...
# 77339       31-60 minutes       Yes
# 79795                 NaN       Yes
# 83862        0-10 minutes       Yes
# 84299         60+ minutes       Yes
# 86012       11-30 minutes       Yes
#
#                                                    SOPartFreq  \
# Respondent
# 8                         Less than once per month or monthly
# 10                            A few times per month or weekly
# 15                        Less than once per month or monthly
# 50                        Less than once per month or monthly
# 65                                       A few times per week
# ...                                                       ...
# 77339       I have never participated in Q&A on Stack Over...
# 79795       I have never participated in Q&A on Stack Over...
# 83862       I have never participated in Q&A on Stack Over...
# 84299                     Less than once per month or monthly
# 86012                                                     NaN
#
#                                                        SOJobs  \
# Respondent
# 8                                                         Yes
# 10                                                        Yes
# 15                                                        Yes
# 50          No, I knew that Stack Overflow had a job board...
# 65          No, I knew that Stack Overflow had a job board...
# ...                                                       ...
# 77339       No, I didn't know that Stack Overflow had a jo...
# 79795       No, I didn't know that Stack Overflow had a jo...
# 83862                                                     Yes
# 84299                                                     Yes
# 86012       No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 8                         No, and I don't know what those are
# 10                        No, and I don't know what those are
# 15          No, I've heard of them, but I am not part of a...
# 50                        No, and I don't know what those are
# 65                        No, and I don't know what those are
# ...                                                       ...
# 77339       No, I've heard of them, but I am not part of a...
# 79795                     No, and I don't know what those are
# 83862                     No, and I don't know what those are
# 84299                     No, and I don't know what those are
# 86012                                                     Yes
#
#                      SOComm  \
# Respondent
# 8           Yes, definitely
# 10            Yes, somewhat
# 15            Yes, somewhat
# 50          Yes, definitely
# 65                 Not sure
# ...                     ...
# 77339         Yes, somewhat
# 79795               Neutral
# 83862       Yes, definitely
# 84299         Yes, somewhat
# 86012         Yes, somewhat
#
#                                                 WelcomeChange  \
# Respondent
# 8                       A lot more welcome now than last year
# 10                   Somewhat less welcome now than last year
# 15                    Just as welcome now as I felt last year
# 50                    Just as welcome now as I felt last year
# 65                      A lot more welcome now than last year
# ...                                                       ...
# 77339       Not applicable - I did not use Stack Overflow ...
# 79795                Somewhat more welcome now than last year
# 83862                 Just as welcome now as I felt last year
# 84299                Somewhat more welcome now than last year
# 86012       Not applicable - I did not use Stack Overflow ...
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 8           Tech articles written by other developers;Indu...  24.0    Man
# 10          Tech articles written by other developers;Tech...   NaN    NaN
# 15          Tech articles written by other developers;Indu...  20.0    Man
# 50          Tech articles written by other developers;Tech...  23.0    Man
# 65                                                        NaN  21.0    Man
# ...                                                       ...   ...    ...
# 77339       Tech articles written by other developers;Indu...   NaN    NaN
# 79795       Tech meetups or events in your area;Courses on...   NaN    Man
# 83862       Tech articles written by other developers;Indu...  24.0    Man
# 84299                                                     NaN   NaN    NaN
# 86012       Industry news about technologies you're intere...  24.0    Man
#
#            Trans                Sexuality    Ethnicity Dependents  \
# Respondent
# 8             No  Straight / Heterosexual          NaN        NaN
# 10           NaN                      NaN          NaN        Yes
# 15            No                      NaN          NaN        Yes
# 50            No                      NaN  South Asian         No
# 65            No                      NaN          NaN        Yes
# ...          ...                      ...          ...        ...
# 77339        NaN                      NaN          NaN        NaN
# 79795         No  Straight / Heterosexual          NaN         No
# 83862         No  Straight / Heterosexual          NaN        Yes
# 84299        NaN                      NaN          NaN        NaN
# 86012         No                      NaN  South Asian        NaN
#
#                      SurveyLength                  SurveyEase
# Respondent
# 8           Appropriate in length  Neither easy nor difficult
# 10                       Too long                   Difficult
# 15                       Too long  Neither easy nor difficult
# 50                       Too long                        Easy
# 65          Appropriate in length  Neither easy nor difficult
# ...                           ...                         ...
# 77339                         NaN                         NaN
# 79795                    Too long                   Difficult
# 83862                    Too long  Neither easy nor difficult
# 84299                         NaN                         NaN
# 86012       Appropriate in length                        Easy
#
# [9061 rows x 84 columns]

# %%
india_df.to_csv('data/modified.csv')

# %%
india_df.to_csv('data/modified.tsv', sep='\t')

# %%
india_df.to_excel('data/modified.xlsx')

# %%
test = pd.read_excel('data/modified.xlsx', index_col='Respondent')

# %%
test
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# 15                                                      Never
# 50                                 Once a month or more often
# 65                                                      Never
# ...                                                       ...
# 77339                                 Less than once per year
# 79795       Less than once a month but more than once per ...
# 83862                              Once a month or more often
# 84299                                                   Never
# 86012                              Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# 65                                                        NaN
# ...                                                       ...
# 77339       OSS is, on average, of HIGHER quality than pro...
# 79795       OSS is, on average, of HIGHER quality than pro...
# 83862       OSS is, on average, of HIGHER quality than pro...
# 84299       The quality of OSS and closed source software ...
# 86012       OSS is, on average, of HIGHER quality than pro...
#
#                                     Employment Country         Student  \
# Respondent
# 8           Not employed, but looking for work   India             NaN
# 10                          Employed full-time   India              No
# 15          Not employed, but looking for work   India  Yes, full-time
# 50                          Employed full-time   India              No
# 65                          Employed full-time   India              No
# ...                                        ...     ...             ...
# 77339                       Employed full-time   India  Yes, full-time
# 79795                       Employed full-time   India              No
# 83862                       Employed full-time   India  Yes, full-time
# 84299                       Employed full-time   India  Yes, full-time
# 86012                       Employed full-time   India              No
#
#                                                       EdLevel  \
# Respondent
# 8                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 10                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 15          Secondary school (e.g. American high school, G...
# 50                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 65                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                       ...
# 77339                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 79795                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 83862                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 84299                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 86012             Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                                UndergradMajor  \
# Respondent
# 8           Computer science, computer engineering, or sof...
# 10                                                        NaN
# 15                                                        NaN
# 50          Another engineering discipline (ex. civil, ele...
# 65          Information systems, information technology, o...
# ...                                                       ...
# 77339       Another engineering discipline (ex. civil, ele...
# 79795       Computer science, computer engineering, or sof...
# 83862                                                     NaN
# 84299                           Web development or web design
# 86012       Another engineering discipline (ex. civil, ele...
#
#                                                      EduOther  \
# Respondent
# 8           Taught yourself a new language, framework, or ...
# 10                                                        NaN
# 15          Taken an online course in programming or softw...
# 50          Received on-the-job training in software devel...
# 65                                                        NaN
# ...                                                       ...
# 77339       Taken an online course in programming or softw...
# 79795       Taken an online course in programming or softw...
# 83862                             Participated in a hackathon
# 84299       Taken an online course in programming or softw...
# 86012       Taught yourself a new language, framework, or ...
#
#                              OrgSize  \
# Respondent
# 8                                NaN
# 10          10,000 or more employees
# 15                               NaN
# 50          10,000 or more employees
# 65                20 to 99 employees
# ...                              ...
# 77339       1,000 to 4,999 employees
# 79795           500 to 999 employees
# 83862                            NaN
# 84299           100 to 499 employees
# 86012           100 to 499 employees
#
#                                                       DevType YearsCode  \
# Respondent
# 8              Developer, back-end;Engineer, site reliability         8
# 10          Data or business analyst;Data scientist or mac...        12
# 15                                                    Student         3
# 50                      Developer, back-end;DevOps specialist         7
# 65                     Developer, front-end;Developer, mobile         2
# ...                                                       ...       ...
# 77339                                                     NaN         1
# 79795                                   Developer, QA or test         6
# 83862                        Data or business analyst;Student         1
# 84299       Developer, back-end;Developer, front-end;Devel...        12
# 86012                            Academic researcher;Educator         5
#
#            Age1stCode      YearsCodePro              CareerSat  \
# Respondent
# 8                  16               NaN                    NaN
# 10                 20                10  Slightly dissatisfied
# 15                 13               NaN                    NaN
# 50                 15                 2     Slightly satisfied
# 65                 17                 2         Very satisfied
# ...               ...               ...                    ...
# 77339              27                 1                    NaN
# 79795              17                 5                    NaN
# 83862              18  Less than 1 year                    NaN
# 84299              25                12                    NaN
# 86012              15               NaN                    NaN
#
#                            JobSat            MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 8                             NaN                 NaN       NaN       NaN
# 10          Slightly dissatisfied  Somewhat confident       Yes       Yes
# 15                            NaN                 NaN       NaN       NaN
# 50                 Very satisfied      Very confident  Not sure       Yes
# 65                 Very satisfied      Very confident        No  Not sure
# ...                           ...                 ...       ...       ...
# 77339                         NaN  Somewhat confident       Yes       Yes
# 79795                         NaN  Somewhat confident        No  Not sure
# 83862                         NaN      Very confident  Not sure       Yes
# 84299                         NaN                 NaN       NaN       NaN
# 86012                         NaN  Somewhat confident        No  Not sure
#
#                                                       JobSeek  \
# Respondent
# 8                                                         NaN
# 10          I’m not actively looking, but I am open to new...
# 15          I’m not actively looking, but I am open to new...
# 50          I’m not actively looking, but I am open to new...
# 65          I’m not actively looking, but I am open to new...
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                                     NaN
# 86012                                                     NaN
#
#                     LastHireDate  \
# Respondent
# 8                            NaN
# 10                 3-4 years ago
# 15          I've never had a job
# 50                 1-2 years ago
# 65          Less than a year ago
# ...                          ...
# 77339                        NaN
# 79795                        NaN
# 83862                        NaN
# 84299                        NaN
# 86012                        NaN
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 8                                                         NaN      NaN
# 10                                                        NaN       No
# 15                                                        NaN      NaN
# 50          Write code by hand (e.g., on a whiteboard);Int...       No
# 65          Write any code;Solve a brain-teaser style puzz...       No
# ...                                                       ...      ...
# 77339                                                     NaN      NaN
# 79795                                                     NaN      NaN
# 83862                                                     NaN      NaN
# 84299                                                     NaN      NaN
# 86012                                                     NaN      NaN
#
#                                                    JobFactors  \
# Respondent
# 8                                                         NaN
# 10          Languages, frameworks, and other technologies ...
# 15          Industry that I'd be working in;Languages, fra...
# 50          Specific department or team I'd be working on;...
# 65          Languages, frameworks, and other technologies ...
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                                     NaN
# 86012                                                     NaN
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 8                                                         NaN            NaN
# 10                                                        NaN            INR
# 15          Something else changed (education, award, medi...            NaN
# 50                           I was preparing for a job search            INR
# 65           My job status changed (promotion, new job, etc.)            INR
# ...                                                       ...            ...
# 77339                                                     NaN            NaN
# 79795                                                     NaN            NaN
# 83862                                                     NaN            NaN
# 84299                                                     NaN            NaN
# 86012                                                     NaN            NaN
#
#             CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# Respondent
# 8                    NaN        NaN      NaN            NaN          NaN
# 10          Indian rupee   950000.0   Yearly        13293.0         70.0
# 15                   NaN        NaN      NaN            NaN          NaN
# 50          Indian rupee   400000.0   Yearly         5597.0          7.0
# 65          Indian rupee        NaN  Monthly            NaN         48.0
# ...                  ...        ...      ...            ...          ...
# 77339                NaN        NaN      NaN            NaN          NaN
# 79795                NaN        NaN      NaN            NaN          NaN
# 83862                NaN        NaN      NaN            NaN          NaN
# 84299                NaN        NaN      NaN            NaN          NaN
# 86012                NaN        NaN      NaN            NaN          NaN
#
#                                                      WorkPlan  \
# Respondent
# 8                                                         NaN
# 10          There's no schedule or spec; I work on what se...
# 15                                                        NaN
# 50          There is a schedule and/or spec (made by me or...
# 65          There's no schedule or spec; I work on what se...
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                                     NaN
# 86012                                                     NaN
#
#                             WorkChallenge                        WorkRemote  \
# Respondent
# 8                                     NaN                               NaN
# 10                                    NaN             A few days each month
# 15                                    NaN                               NaN
# 50          Meetings;Time spent commuting  Less than once per month / Never
# 65                                    NaN               About half the time
# ...                                   ...                               ...
# 77339                                 NaN                               NaN
# 79795                                 NaN                               NaN
# 83862                                 NaN                               NaN
# 84299                                 NaN                               NaN
# 86012                                 NaN                               NaN
#
#                                                    WorkLoc             ImpSyn  \
# Respondent
# 8                                                      NaN                NaN
# 10                                                    Home  Far above average
# 15                                                     NaN                NaN
# 50          Other place, such as a coworking space or cafe            Average
# 65                                                  Office            Average
# ...                                                    ...                ...
# 77339                                                  NaN                NaN
# 79795                                                  NaN                NaN
# 83862                                                  NaN                NaN
# 84299                                                  NaN                NaN
# 86012                                                  NaN                NaN
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 8                                               NaN         NaN
# 10          Yes, because I see value in code review         4.0
# 15                                              NaN         NaN
# 50                                               No         NaN
# 65          Yes, because I see value in code review         NaN
# ...                                             ...         ...
# 77339                                           NaN         NaN
# 79795                                           NaN         NaN
# 83862                                           NaN         NaN
# 84299                                           NaN         NaN
# 86012                                           NaN         NaN
#
#                                                     UnitTests  \
# Respondent
# 8                                                         NaN
# 10                              Yes, it's part of our process
# 15                                                        NaN
# 50          Yes, it's not part of our process but the deve...
# 65          Yes, it's not part of our process but the deve...
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                                     NaN
# 86012                                                     NaN
#
#                                                   PurchaseHow  \
# Respondent
# 8                                                         NaN
# 10                                                        NaN
# 15                                                        NaN
# 50          The CTO, CIO, or other management purchase new...
# 65                                                   Not sure
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                                     NaN
# 86012                                                     NaN
#
#                              PurchaseWhat  \
# Respondent
# 8                                     NaN
# 10                                    NaN
# 15                                    NaN
# 50          I have little or no influence
# 65                                    NaN
# ...                                   ...
# 77339                                 NaN
# 79795                                 NaN
# 83862                                 NaN
# 84299                                 NaN
# 86012                                 NaN
#
#                                            LanguageWorkedWith  \
# Respondent
# 8           Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 10                              C#;Go;JavaScript;Python;R;SQL
# 15          Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 50          Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 65                            Assembly;C;C++;C#;HTML/CSS;Java
# ...                                                       ...
# 77339                                               Other(s):
# 79795                    Bash/Shell/PowerShell;Python;SQL;VBA
# 83862       Assembly;C;C++;HTML/CSS;Java;JavaScript;Object...
# 84299        HTML/CSS;Java;JavaScript;Python;Swift;TypeScript
# 86012           Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript
#
#                                        LanguageDesireNextYear  \
# Respondent
# 8           Bash/Shell/PowerShell;C;C++;Elixir;Erlang;Go;P...
# 10                       C#;Go;JavaScript;Kotlin;Python;R;SQL
# 15          Assembly;Bash/Shell/PowerShell;C;C++;C#;Go;HTM...
# 50                                 HTML/CSS;JavaScript;Python
# 65                                                     Kotlin
# ...                                                       ...
# 77339                                              Python;SQL
# 79795                                                     NaN
# 83862                                                     NaN
# 84299                                HTML/CSS;Java;JavaScript
# 86012                                              C++;Python
#
#                                            DatabaseWorkedWith  \
# Respondent
# 8           Cassandra;Elasticsearch;MongoDB;MySQL;Oracle;R...
# 10          Elasticsearch;MongoDB;Microsoft SQL Server;MyS...
# 15                                MariaDB;MySQL;Oracle;SQLite
# 50          Elasticsearch;Firebase;MariaDB;MongoDB;MySQL;O...
# 65                               Firebase;MySQL;Oracle;SQLite
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                   MySQL
# 84299                                    MongoDB;Redis;SQLite
# 86012                                                   MySQL
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 8           Cassandra;DynamoDB;Elasticsearch;Firebase;Mong...
# 10                 Elasticsearch;MongoDB;Microsoft SQL Server
# 15          MariaDB;MongoDB;Microsoft SQL Server;MySQL;Ora...
# 50                        Firebase;PostgreSQL;Redis;Other(s):
# 65                                            Firebase;SQLite
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                          DynamoDB;Elasticsearch;MongoDB
# 84299                                           MongoDB;Redis
# 86012                                                     NaN
#
#                                            PlatformWorkedWith  \
# Respondent
# 8                         AWS;Docker;Heroku;Linux;MacOS;Slack
# 10                                              Linux;Windows
# 15                                              Linux;Windows
# 50          Arduino;AWS;Heroku;Linux;MacOS;Raspberry Pi;Wo...
# 65                                                    Android
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862             Android;AWS;Google Cloud Platform;WordPress
# 84299                                                     NaN
# 86012                                               Other(s):
#
#                                        PlatformDesireNextYear  \
# Respondent
# 8           Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 10                         Android;Linux;Raspberry Pi;Windows
# 15          Android;Google Cloud Platform;iOS;Linux;MacOS;...
# 50          AWS;Docker;Heroku;Kubernetes;Linux;MacOS;WordP...
# 65                                                    Android
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                     IBM Cloud or Watson
# 84299                                                     NaN
# 86012                                               Other(s):
#
#                                            WebFrameWorkedWith  \
# Respondent
# 8                               Express;Flask;React.js;Spring
# 10          Angular/Angular.js;ASP.NET;Django;Express;Flas...
# 15                                                        NaN
# 50                                Django;Express;Flask;jQuery
# 65                                                    ASP.NET
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                 Laravel
# 84299       Angular/Angular.js;Express;jQuery;React.js;Oth...
# 86012                                                     NaN
#
#                                        WebFrameDesireNextYear  \
# Respondent
# 8                        Django;Express;Flask;React.js;Vue.js
# 10          Angular/Angular.js;ASP.NET;Django;Express;Flas...
# 15          Angular/Angular.js;ASP.NET;Django;Drupal;jQuer...
# 50                       Express;Flask;jQuery;React.js;Vue.js
# 65                                                        NaN
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                       Angular/Angular.js;Laravel;Vue.js
# 84299                              Express;React.js;Other(s):
# 86012                                                     NaN
#
#                            MiscTechWorkedWith  \
# Respondent
# 8                       Hadoop;Node.js;Pandas
# 10          .NET;Node.js;Pandas;Torch/PyTorch
# 15                                        NaN
# 50                                    Node.js
# 65                                        NaN
# ...                                       ...
# 77339                                     NaN
# 79795                Apache Spark;Chef;Puppet
# 83862                                     NaN
# 84299                                 Node.js
# 86012                                     NaN
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 8           Ansible;Apache Spark;Chef;Hadoop;Node.js;Panda...
# 10                      .NET;Node.js;TensorFlow;Torch/PyTorch
# 15          .NET;.NET Core;Node.js;TensorFlow;Unity 3D;Unr...
# 50                                                    Node.js
# 65                                                        NaN
# ...                                                       ...
# 77339                                                     NaN
# 79795                                                     NaN
# 83862                                                 Node.js
# 84299                                                 Node.js
# 86012                                                     NaN
#
#                                                    DevEnviron        OpSys  \
# Respondent
# 8           Atom;IntelliJ;IPython / Jupyter;PyCharm;Visual...  Linux-based
# 10          Android Studio;Eclipse;IPython / Jupyter;Notep...      Windows
# 15                   Atom;NetBeans;Notepad++;Sublime Text;Vim  Linux-based
# 50                               Notepad++;Visual Studio Code        MacOS
# 65                                    Android Studio;IntelliJ  Linux-based
# ...                                                       ...          ...
# 77339                                                     NaN  Linux-based
# 79795                                             PyCharm;Vim  Linux-based
# 83862       Android Studio;Atom;IntelliJ;Komodo;NetBeans;N...      Windows
# 84299             IntelliJ;Notepad++;Visual Studio Code;Xcode      Windows
# 86012                                               Notepad++  Linux-based
#
#                                                    Containers BlockchainOrg  \
# Respondent
# 8           Development;Testing;Production;Outside of work...           NaN
# 10                                                        NaN    Not at all
# 15                                                Development           NaN
# 50                                                    Testing    Not at all
# 65                                                        NaN           NaN
# ...                                                       ...           ...
# 77339                                 I do not use containers           NaN
# 79795       Development;Testing;Production;Outside of work...    Not at all
# 83862                                 I do not use containers           NaN
# 84299                                                     NaN           NaN
# 86012                                 I do not use containers           NaN
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 8           Useful across many domains and could change ma...        Yes
# 10          Useful for immutable record keeping outside of...         No
# 15                                                        NaN        Yes
# 50          Useful for immutable record keeping outside of...        Yes
# 65                                                        NaN        Yes
# ...                                                       ...        ...
# 77339                                                     NaN        Yes
# 79795                                                     NaN         No
# 83862       Useful across many domains and could change ma...         No
# 84299                                                     NaN        Yes
# 86012                                                     NaN         No
#
#                                             ITperson  OffOn  \
# Respondent
# 8                                               SIGH    Yes
# 10                                               Yes    Yes
# 15                                               Yes  What?
# 50                                          Also Yes  What?
# 65                                               Yes  What?
# ...                                              ...    ...
# 77339                                            Yes     No
# 79795                                            Yes  What?
# 83862                                            Yes  What?
# 84299       Fortunately, someone else has that title  What?
# 86012                                       Also Yes  What?
#
#                          SocialMedia              Extraversion   ScreenName  \
# Respondent
# 8                            YouTube  In real life (in person)       Handle
# 10                           YouTube                   Neither  Screen Name
# 15                           YouTube  In real life (in person)          NaN
# 50                           YouTube  In real life (in person)     Username
# 65                          WhatsApp  In real life (in person)          NaN
# ...                              ...                       ...          ...
# 77339                        YouTube                    Online       UserID
# 79795                      Instagram  In real life (in person)     Username
# 83862                        Twitter                    Online       UserID
# 84299                       LinkedIn                       NaN          NaN
# 86012       I don't use social media                    Online     Username
#
#            SOVisit1st                          SOVisitFreq  \
# Respondent
# 8                2012                 A few times per week
# 10                NaN               Multiple times per day
# 15               2018                Daily or almost daily
# 50               2012                Daily or almost daily
# 65               2017               Multiple times per day
# ...               ...                                  ...
# 77339            2019  Less than once per month or monthly
# 79795            2018      A few times per month or weekly
# 83862            2012      A few times per month or weekly
# 84299            2011      A few times per month or weekly
# 86012            2014      A few times per month or weekly
#
#                                                     SOVisitTo  \
# Respondent
# 8           Find answers to specific questions;Learn how t...
# 10          Find answers to specific questions;Get a sense...
# 15          Find answers to specific questions;Learn how t...
# 50          Find answers to specific questions;Learn how t...
# 65                         Find answers to specific questions
# ...                                                       ...
# 77339       Find answers to specific questions;Learn how t...
# 79795                      Find answers to specific questions
# 83862       Find answers to specific questions;Learn how t...
# 84299       Find answers to specific questions;Contribute ...
# 86012                      Find answers to specific questions
#
#                            SOFindAnswer                         SOTimeSaved  \
# Respondent
# 8               Less than once per week  Stack Overflow was slightly faster
# 10                   3-5 times per week            They were about the same
# 15          More than 10 times per week            They were about the same
# 50                   3-5 times per week  Stack Overflow was slightly faster
# 65          More than 10 times per week  Stack Overflow was slightly faster
# ...                                 ...                                 ...
# 77339                1-2 times per week      Stack Overflow was much faster
# 79795           Less than once per week            They were about the same
# 83862           Less than once per week      Stack Overflow was much faster
# 84299           Less than once per week      Stack Overflow was much faster
# 86012           Less than once per week      Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount  \
# Respondent
# 8           11-30 minutes       Yes
# 10                    NaN       Yes
# 15                    NaN       Yes
# 50          11-30 minutes       Yes
# 65          11-30 minutes       Yes
# ...                   ...       ...
# 77339       31-60 minutes       Yes
# 79795                 NaN       Yes
# 83862        0-10 minutes       Yes
# 84299         60+ minutes       Yes
# 86012       11-30 minutes       Yes
#
#                                                    SOPartFreq  \
# Respondent
# 8                         Less than once per month or monthly
# 10                            A few times per month or weekly
# 15                        Less than once per month or monthly
# 50                        Less than once per month or monthly
# 65                                       A few times per week
# ...                                                       ...
# 77339       I have never participated in Q&A on Stack Over...
# 79795       I have never participated in Q&A on Stack Over...
# 83862       I have never participated in Q&A on Stack Over...
# 84299                     Less than once per month or monthly
# 86012                                                     NaN
#
#                                                        SOJobs  \
# Respondent
# 8                                                         Yes
# 10                                                        Yes
# 15                                                        Yes
# 50          No, I knew that Stack Overflow had a job board...
# 65          No, I knew that Stack Overflow had a job board...
# ...                                                       ...
# 77339       No, I didn't know that Stack Overflow had a jo...
# 79795       No, I didn't know that Stack Overflow had a jo...
# 83862                                                     Yes
# 84299                                                     Yes
# 86012       No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 8                         No, and I don't know what those are
# 10                        No, and I don't know what those are
# 15          No, I've heard of them, but I am not part of a...
# 50                        No, and I don't know what those are
# 65                        No, and I don't know what those are
# ...                                                       ...
# 77339       No, I've heard of them, but I am not part of a...
# 79795                     No, and I don't know what those are
# 83862                     No, and I don't know what those are
# 84299                     No, and I don't know what those are
# 86012                                                     Yes
#
#                      SOComm  \
# Respondent
# 8           Yes, definitely
# 10            Yes, somewhat
# 15            Yes, somewhat
# 50          Yes, definitely
# 65                 Not sure
# ...                     ...
# 77339         Yes, somewhat
# 79795               Neutral
# 83862       Yes, definitely
# 84299         Yes, somewhat
# 86012         Yes, somewhat
#
#                                                 WelcomeChange  \
# Respondent
# 8                       A lot more welcome now than last year
# 10                   Somewhat less welcome now than last year
# 15                    Just as welcome now as I felt last year
# 50                    Just as welcome now as I felt last year
# 65                      A lot more welcome now than last year
# ...                                                       ...
# 77339       Not applicable - I did not use Stack Overflow ...
# 79795                Somewhat more welcome now than last year
# 83862                 Just as welcome now as I felt last year
# 84299                Somewhat more welcome now than last year
# 86012       Not applicable - I did not use Stack Overflow ...
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 8           Tech articles written by other developers;Indu...  24.0    Man
# 10          Tech articles written by other developers;Tech...   NaN    NaN
# 15          Tech articles written by other developers;Indu...  20.0    Man
# 50          Tech articles written by other developers;Tech...  23.0    Man
# 65                                                        NaN  21.0    Man
# ...                                                       ...   ...    ...
# 77339       Tech articles written by other developers;Indu...   NaN    NaN
# 79795       Tech meetups or events in your area;Courses on...   NaN    Man
# 83862       Tech articles written by other developers;Indu...  24.0    Man
# 84299                                                     NaN   NaN    NaN
# 86012       Industry news about technologies you're intere...  24.0    Man
#
#            Trans                Sexuality    Ethnicity Dependents  \
# Respondent
# 8             No  Straight / Heterosexual          NaN        NaN
# 10           NaN                      NaN          NaN        Yes
# 15            No                      NaN          NaN        Yes
# 50            No                      NaN  South Asian         No
# 65            No                      NaN          NaN        Yes
# ...          ...                      ...          ...        ...
# 77339        NaN                      NaN          NaN        NaN
# 79795         No  Straight / Heterosexual          NaN         No
# 83862         No  Straight / Heterosexual          NaN        Yes
# 84299        NaN                      NaN          NaN        NaN
# 86012         No                      NaN  South Asian        NaN
#
#                      SurveyLength                  SurveyEase
# Respondent
# 8           Appropriate in length  Neither easy nor difficult
# 10                       Too long                   Difficult
# 15                       Too long  Neither easy nor difficult
# 50                       Too long                        Easy
# 65          Appropriate in length  Neither easy nor difficult
# ...                           ...                         ...
# 77339                         NaN                         NaN
# 79795                    Too long                   Difficult
# 83862                    Too long  Neither easy nor difficult
# 84299                         NaN                         NaN
# 86012       Appropriate in length                        Easy
#
# [9061 rows x 84 columns]

# %%
india_df.to_json('data/modified.json')

# %%
test = pd.read_json('data/modified.json')

# %%
test
# Out:
#                                    MainBranch Hobbyist  \
# 8                 I code primarily as a hobby      Yes
# 10             I am a developer by profession      Yes
# 15     I am a student who is learning to code      Yes
# 50             I am a developer by profession      Yes
# 65             I am a developer by profession      Yes
# ...                                       ...      ...
# 77339                                    None      Yes
# 79795                                    None      Yes
# 83862                                    None      Yes
# 84299                                    None      Yes
# 86012                                    None      Yes
#
#                                              OpenSourcer  \
# 8                                Less than once per year
# 10                            Once a month or more often
# 15                                                 Never
# 50                            Once a month or more often
# 65                                                 Never
# ...                                                  ...
# 77339                            Less than once per year
# 79795  Less than once a month but more than once per ...
# 83862                         Once a month or more often
# 84299                                              Never
# 86012                         Once a month or more often
#
#                                               OpenSource  \
# 8      OSS is, on average, of HIGHER quality than pro...
# 10     OSS is, on average, of HIGHER quality than pro...
# 15     OSS is, on average, of HIGHER quality than pro...
# 50     OSS is, on average, of LOWER quality than prop...
# 65                                                  None
# ...                                                  ...
# 77339  OSS is, on average, of HIGHER quality than pro...
# 79795  OSS is, on average, of HIGHER quality than pro...
# 83862  OSS is, on average, of HIGHER quality than pro...
# 84299  The quality of OSS and closed source software ...
# 86012  OSS is, on average, of HIGHER quality than pro...
#
#                                Employment Country         Student  \
# 8      Not employed, but looking for work   India            None
# 10                     Employed full-time   India              No
# 15     Not employed, but looking for work   India  Yes, full-time
# 50                     Employed full-time   India              No
# 65                     Employed full-time   India              No
# ...                                   ...     ...             ...
# 77339                  Employed full-time   India  Yes, full-time
# 79795                  Employed full-time   India              No
# 83862                  Employed full-time   India  Yes, full-time
# 84299                  Employed full-time   India  Yes, full-time
# 86012                  Employed full-time   India              No
#
#                                                  EdLevel  \
# 8               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 10           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 15     Secondary school (e.g. American high school, G...
# 50              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 65              Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 77339           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 79795           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 83862           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 84299           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 86012        Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                           UndergradMajor  \
# 8      Computer science, computer engineering, or sof...
# 10                                                  None
# 15                                                  None
# 50     Another engineering discipline (ex. civil, ele...
# 65     Information systems, information technology, o...
# ...                                                  ...
# 77339  Another engineering discipline (ex. civil, ele...
# 79795  Computer science, computer engineering, or sof...
# 83862                                               None
# 84299                      Web development or web design
# 86012  Another engineering discipline (ex. civil, ele...
#
#                                                 EduOther  \
# 8      Taught yourself a new language, framework, or ...
# 10                                                  None
# 15     Taken an online course in programming or softw...
# 50     Received on-the-job training in software devel...
# 65                                                  None
# ...                                                  ...
# 77339  Taken an online course in programming or softw...
# 79795  Taken an online course in programming or softw...
# 83862                        Participated in a hackathon
# 84299  Taken an online course in programming or softw...
# 86012  Taught yourself a new language, framework, or ...
#
#                         OrgSize  \
# 8                          None
# 10     10,000 or more employees
# 15                         None
# 50     10,000 or more employees
# 65           20 to 99 employees
# ...                         ...
# 77339  1,000 to 4,999 employees
# 79795      500 to 999 employees
# 83862                      None
# 84299      100 to 499 employees
# 86012      100 to 499 employees
#
#                                                  DevType YearsCode Age1stCode  \
# 8         Developer, back-end;Engineer, site reliability         8         16
# 10     Data or business analyst;Data scientist or mac...        12         20
# 15                                               Student         3         13
# 50                 Developer, back-end;DevOps specialist         7         15
# 65                Developer, front-end;Developer, mobile         2         17
# ...                                                  ...       ...        ...
# 77339                                               None         1         27
# 79795                              Developer, QA or test         6         17
# 83862                   Data or business analyst;Student         1         18
# 84299  Developer, back-end;Developer, front-end;Devel...        12         25
# 86012                       Academic researcher;Educator         5         15
#
#            YearsCodePro              CareerSat                 JobSat  \
# 8                  None                   None                   None
# 10                   10  Slightly dissatisfied  Slightly dissatisfied
# 15                 None                   None                   None
# 50                    2     Slightly satisfied         Very satisfied
# 65                    2         Very satisfied         Very satisfied
# ...                 ...                    ...                    ...
# 77339                 1                   None                   None
# 79795                 5                   None                   None
# 83862  Less than 1 year                   None                   None
# 84299                12                   None                   None
# 86012              None                   None                   None
#
#                  MgrIdiot  MgrMoney   MgrWant  \
# 8                    None      None      None
# 10     Somewhat confident       Yes       Yes
# 15                   None      None      None
# 50         Very confident  Not sure       Yes
# 65         Very confident        No  Not sure
# ...                   ...       ...       ...
# 77339  Somewhat confident       Yes       Yes
# 79795  Somewhat confident        No  Not sure
# 83862      Very confident  Not sure       Yes
# 84299                None      None      None
# 86012  Somewhat confident        No  Not sure
#
#                                                  JobSeek  \
# 8                                                   None
# 10     I’m not actively looking, but I am open to new...
# 15     I’m not actively looking, but I am open to new...
# 50     I’m not actively looking, but I am open to new...
# 65     I’m not actively looking, but I am open to new...
# ...                                                  ...
# 77339                                               None
# 79795                                               None
# 83862                                               None
# 84299                                               None
# 86012                                               None
#
#                LastHireDate  \
# 8                      None
# 10            3-4 years ago
# 15     I've never had a job
# 50            1-2 years ago
# 65     Less than a year ago
# ...                     ...
# 77339                  None
# 79795                  None
# 83862                  None
# 84299                  None
# 86012                  None
#
#                                                  LastInt FizzBuzz  \
# 8                                                   None     None
# 10                                                  None       No
# 15                                                  None     None
# 50     Write code by hand (e.g., on a whiteboard);Int...       No
# 65     Write any code;Solve a brain-teaser style puzz...       No
# ...                                                  ...      ...
# 77339                                               None     None
# 79795                                               None     None
# 83862                                               None     None
# 84299                                               None     None
# 86012                                               None     None
#
#                                               JobFactors  \
# 8                                                   None
# 10     Languages, frameworks, and other technologies ...
# 15     Industry that I'd be working in;Languages, fra...
# 50     Specific department or team I'd be working on;...
# 65     Languages, frameworks, and other technologies ...
# ...                                                  ...
# 77339                                               None
# 79795                                               None
# 83862                                               None
# 84299                                               None
# 86012                                               None
#
#                                             ResumeUpdate CurrencySymbol  \
# 8                                                   None           None
# 10                                                  None            INR
# 15     Something else changed (education, award, medi...           None
# 50                      I was preparing for a job search            INR
# 65      My job status changed (promotion, new job, etc.)            INR
# ...                                                  ...            ...
# 77339                                               None           None
# 79795                                               None           None
# 83862                                               None           None
# 84299                                               None           None
# 86012                                               None           None
#
#        CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 8              None        NaN     None            NaN          NaN
# 10     Indian rupee   950000.0   Yearly        13293.0         70.0
# 15             None        NaN     None            NaN          NaN
# 50     Indian rupee   400000.0   Yearly         5597.0          7.0
# 65     Indian rupee        NaN  Monthly            NaN         48.0
# ...             ...        ...      ...            ...          ...
# 77339          None        NaN     None            NaN          NaN
# 79795          None        NaN     None            NaN          NaN
# 83862          None        NaN     None            NaN          NaN
# 84299          None        NaN     None            NaN          NaN
# 86012          None        NaN     None            NaN          NaN
#
#                                                 WorkPlan  \
# 8                                                   None
# 10     There's no schedule or spec; I work on what se...
# 15                                                  None
# 50     There is a schedule and/or spec (made by me or...
# 65     There's no schedule or spec; I work on what se...
# ...                                                  ...
# 77339                                               None
# 79795                                               None
# 83862                                               None
# 84299                                               None
# 86012                                               None
#
#                        WorkChallenge                        WorkRemote  \
# 8                               None                              None
# 10                              None             A few days each month
# 15                              None                              None
# 50     Meetings;Time spent commuting  Less than once per month / Never
# 65                              None               About half the time
# ...                              ...                               ...
# 77339                           None                              None
# 79795                           None                              None
# 83862                           None                              None
# 84299                           None                              None
# 86012                           None                              None
#
#                                               WorkLoc             ImpSyn  \
# 8                                                None               None
# 10                                               Home  Far above average
# 15                                               None               None
# 50     Other place, such as a coworking space or cafe            Average
# 65                                             Office            Average
# ...                                               ...                ...
# 77339                                            None               None
# 79795                                            None               None
# 83862                                            None               None
# 84299                                            None               None
# 86012                                            None               None
#
#                                        CodeRev  CodeRevHrs  \
# 8                                         None         NaN
# 10     Yes, because I see value in code review         4.0
# 15                                        None         NaN
# 50                                          No         NaN
# 65     Yes, because I see value in code review         NaN
# ...                                        ...         ...
# 77339                                     None         NaN
# 79795                                     None         NaN
# 83862                                     None         NaN
# 84299                                     None         NaN
# 86012                                     None         NaN
#
#                                                UnitTests  \
# 8                                                   None
# 10                         Yes, it's part of our process
# 15                                                  None
# 50     Yes, it's not part of our process but the deve...
# 65     Yes, it's not part of our process but the deve...
# ...                                                  ...
# 77339                                               None
# 79795                                               None
# 83862                                               None
# 84299                                               None
# 86012                                               None
#
#                                              PurchaseHow  \
# 8                                                   None
# 10                                                  None
# 15                                                  None
# 50     The CTO, CIO, or other management purchase new...
# 65                                              Not sure
# ...                                                  ...
# 77339                                               None
# 79795                                               None
# 83862                                               None
# 84299                                               None
# 86012                                               None
#
#                         PurchaseWhat  \
# 8                               None
# 10                              None
# 15                              None
# 50     I have little or no influence
# 65                              None
# ...                              ...
# 77339                           None
# 79795                           None
# 83862                           None
# 84299                           None
# 86012                           None
#
#                                       LanguageWorkedWith  \
# 8      Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 10                         C#;Go;JavaScript;Python;R;SQL
# 15     Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 50     Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 65                       Assembly;C;C++;C#;HTML/CSS;Java
# ...                                                  ...
# 77339                                          Other(s):
# 79795               Bash/Shell/PowerShell;Python;SQL;VBA
# 83862  Assembly;C;C++;HTML/CSS;Java;JavaScript;Object...
# 84299   HTML/CSS;Java;JavaScript;Python;Swift;TypeScript
# 86012      Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript
#
#                                   LanguageDesireNextYear  \
# 8      Bash/Shell/PowerShell;C;C++;Elixir;Erlang;Go;P...
# 10                  C#;Go;JavaScript;Kotlin;Python;R;SQL
# 15     Assembly;Bash/Shell/PowerShell;C;C++;C#;Go;HTM...
# 50                            HTML/CSS;JavaScript;Python
# 65                                                Kotlin
# ...                                                  ...
# 77339                                         Python;SQL
# 79795                                               None
# 83862                                               None
# 84299                           HTML/CSS;Java;JavaScript
# 86012                                         C++;Python
#
#                                       DatabaseWorkedWith  \
# 8      Cassandra;Elasticsearch;MongoDB;MySQL;Oracle;R...
# 10     Elasticsearch;MongoDB;Microsoft SQL Server;MyS...
# 15                           MariaDB;MySQL;Oracle;SQLite
# 50     Elasticsearch;Firebase;MariaDB;MongoDB;MySQL;O...
# 65                          Firebase;MySQL;Oracle;SQLite
# ...                                                  ...
# 77339                                               None
# 79795                                               None
# 83862                                              MySQL
# 84299                               MongoDB;Redis;SQLite
# 86012                                              MySQL
#
#                                   DatabaseDesireNextYear  \
# 8      Cassandra;DynamoDB;Elasticsearch;Firebase;Mong...
# 10            Elasticsearch;MongoDB;Microsoft SQL Server
# 15     MariaDB;MongoDB;Microsoft SQL Server;MySQL;Ora...
# 50                   Firebase;PostgreSQL;Redis;Other(s):
# 65                                       Firebase;SQLite
# ...                                                  ...
# 77339                                               None
# 79795                                               None
# 83862                     DynamoDB;Elasticsearch;MongoDB
# 84299                                      MongoDB;Redis
# 86012                                               None
#
#                                       PlatformWorkedWith  \
# 8                    AWS;Docker;Heroku;Linux;MacOS;Slack
# 10                                         Linux;Windows
# 15                                         Linux;Windows
# 50     Arduino;AWS;Heroku;Linux;MacOS;Raspberry Pi;Wo...
# 65                                               Android
# ...                                                  ...
# 77339                                               None
# 79795                                               None
# 83862        Android;AWS;Google Cloud Platform;WordPress
# 84299                                               None
# 86012                                          Other(s):
#
#                                   PlatformDesireNextYear  \
# 8      Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 10                    Android;Linux;Raspberry Pi;Windows
# 15     Android;Google Cloud Platform;iOS;Linux;MacOS;...
# 50     AWS;Docker;Heroku;Kubernetes;Linux;MacOS;WordP...
# 65                                               Android
# ...                                                  ...
# 77339                                               None
# 79795                                               None
# 83862                                IBM Cloud or Watson
# 84299                                               None
# 86012                                          Other(s):
#
#                                       WebFrameWorkedWith  \
# 8                          Express;Flask;React.js;Spring
# 10     Angular/Angular.js;ASP.NET;Django;Express;Flas...
# 15                                                  None
# 50                           Django;Express;Flask;jQuery
# 65                                               ASP.NET
# ...                                                  ...
# 77339                                               None
# 79795                                               None
# 83862                                            Laravel
# 84299  Angular/Angular.js;Express;jQuery;React.js;Oth...
# 86012                                               None
#
#                                   WebFrameDesireNextYear  \
# 8                   Django;Express;Flask;React.js;Vue.js
# 10     Angular/Angular.js;ASP.NET;Django;Express;Flas...
# 15     Angular/Angular.js;ASP.NET;Django;Drupal;jQuer...
# 50                  Express;Flask;jQuery;React.js;Vue.js
# 65                                                  None
# ...                                                  ...
# 77339                                               None
# 79795                                               None
# 83862                  Angular/Angular.js;Laravel;Vue.js
# 84299                         Express;React.js;Other(s):
# 86012                                               None
#
#                       MiscTechWorkedWith  \
# 8                  Hadoop;Node.js;Pandas
# 10     .NET;Node.js;Pandas;Torch/PyTorch
# 15                                  None
# 50                               Node.js
# 65                                  None
# ...                                  ...
# 77339                               None
# 79795           Apache Spark;Chef;Puppet
# 83862                               None
# 84299                            Node.js
# 86012                               None
#
#                                   MiscTechDesireNextYear  \
# 8      Ansible;Apache Spark;Chef;Hadoop;Node.js;Panda...
# 10                 .NET;Node.js;TensorFlow;Torch/PyTorch
# 15     .NET;.NET Core;Node.js;TensorFlow;Unity 3D;Unr...
# 50                                               Node.js
# 65                                                  None
# ...                                                  ...
# 77339                                               None
# 79795                                               None
# 83862                                            Node.js
# 84299                                            Node.js
# 86012                                               None
#
#                                               DevEnviron        OpSys  \
# 8      Atom;IntelliJ;IPython / Jupyter;PyCharm;Visual...  Linux-based
# 10     Android Studio;Eclipse;IPython / Jupyter;Notep...      Windows
# 15              Atom;NetBeans;Notepad++;Sublime Text;Vim  Linux-based
# 50                          Notepad++;Visual Studio Code        MacOS
# 65                               Android Studio;IntelliJ  Linux-based
# ...                                                  ...          ...
# 77339                                               None  Linux-based
# 79795                                        PyCharm;Vim  Linux-based
# 83862  Android Studio;Atom;IntelliJ;Komodo;NetBeans;N...      Windows
# 84299        IntelliJ;Notepad++;Visual Studio Code;Xcode      Windows
# 86012                                          Notepad++  Linux-based
#
#                                               Containers BlockchainOrg  \
# 8      Development;Testing;Production;Outside of work...          None
# 10                                                  None    Not at all
# 15                                           Development          None
# 50                                               Testing    Not at all
# 65                                                  None          None
# ...                                                  ...           ...
# 77339                            I do not use containers          None
# 79795  Development;Testing;Production;Outside of work...    Not at all
# 83862                            I do not use containers          None
# 84299                                               None          None
# 86012                            I do not use containers          None
#
#                                             BlockchainIs BetterLife  \
# 8      Useful across many domains and could change ma...        Yes
# 10     Useful for immutable record keeping outside of...         No
# 15                                                  None        Yes
# 50     Useful for immutable record keeping outside of...        Yes
# 65                                                  None        Yes
# ...                                                  ...        ...
# 77339                                               None        Yes
# 79795                                               None         No
# 83862  Useful across many domains and could change ma...         No
# 84299                                               None        Yes
# 86012                                               None         No
#
#                                        ITperson  OffOn  \
# 8                                          SIGH    Yes
# 10                                          Yes    Yes
# 15                                          Yes  What?
# 50                                     Also Yes  What?
# 65                                          Yes  What?
# ...                                         ...    ...
# 77339                                       Yes     No
# 79795                                       Yes  What?
# 83862                                       Yes  What?
# 84299  Fortunately, someone else has that title  What?
# 86012                                  Also Yes  What?
#
#                     SocialMedia              Extraversion   ScreenName  \
# 8                       YouTube  In real life (in person)       Handle
# 10                      YouTube                   Neither  Screen Name
# 15                      YouTube  In real life (in person)         None
# 50                      YouTube  In real life (in person)     Username
# 65                     WhatsApp  In real life (in person)         None
# ...                         ...                       ...          ...
# 77339                   YouTube                    Online       UserID
# 79795                 Instagram  In real life (in person)     Username
# 83862                   Twitter                    Online       UserID
# 84299                  LinkedIn                      None         None
# 86012  I don't use social media                    Online     Username
#
#       SOVisit1st                          SOVisitFreq  \
# 8           2012                 A few times per week
# 10          None               Multiple times per day
# 15          2018                Daily or almost daily
# 50          2012                Daily or almost daily
# 65          2017               Multiple times per day
# ...          ...                                  ...
# 77339       2019  Less than once per month or monthly
# 79795       2018      A few times per month or weekly
# 83862       2012      A few times per month or weekly
# 84299       2011      A few times per month or weekly
# 86012       2014      A few times per month or weekly
#
#                                                SOVisitTo  \
# 8      Find answers to specific questions;Learn how t...
# 10     Find answers to specific questions;Get a sense...
# 15     Find answers to specific questions;Learn how t...
# 50     Find answers to specific questions;Learn how t...
# 65                    Find answers to specific questions
# ...                                                  ...
# 77339  Find answers to specific questions;Learn how t...
# 79795                 Find answers to specific questions
# 83862  Find answers to specific questions;Learn how t...
# 84299  Find answers to specific questions;Contribute ...
# 86012                 Find answers to specific questions
#
#                       SOFindAnswer                         SOTimeSaved  \
# 8          Less than once per week  Stack Overflow was slightly faster
# 10              3-5 times per week            They were about the same
# 15     More than 10 times per week            They were about the same
# 50              3-5 times per week  Stack Overflow was slightly faster
# 65     More than 10 times per week  Stack Overflow was slightly faster
# ...                            ...                                 ...
# 77339           1-2 times per week      Stack Overflow was much faster
# 79795      Less than once per week            They were about the same
# 83862      Less than once per week      Stack Overflow was much faster
# 84299      Less than once per week      Stack Overflow was much faster
# 86012      Less than once per week      Stack Overflow was much faster
#
#        SOHowMuchTime SOAccount  \
# 8      11-30 minutes       Yes
# 10              None       Yes
# 15              None       Yes
# 50     11-30 minutes       Yes
# 65     11-30 minutes       Yes
# ...              ...       ...
# 77339  31-60 minutes       Yes
# 79795           None       Yes
# 83862   0-10 minutes       Yes
# 84299    60+ minutes       Yes
# 86012  11-30 minutes       Yes
#
#                                               SOPartFreq  \
# 8                    Less than once per month or monthly
# 10                       A few times per month or weekly
# 15                   Less than once per month or monthly
# 50                   Less than once per month or monthly
# 65                                  A few times per week
# ...                                                  ...
# 77339  I have never participated in Q&A on Stack Over...
# 79795  I have never participated in Q&A on Stack Over...
# 83862  I have never participated in Q&A on Stack Over...
# 84299                Less than once per month or monthly
# 86012                                               None
#
#                                                   SOJobs  \
# 8                                                    Yes
# 10                                                   Yes
# 15                                                   Yes
# 50     No, I knew that Stack Overflow had a job board...
# 65     No, I knew that Stack Overflow had a job board...
# ...                                                  ...
# 77339  No, I didn't know that Stack Overflow had a jo...
# 79795  No, I didn't know that Stack Overflow had a jo...
# 83862                                                Yes
# 84299                                                Yes
# 86012  No, I knew that Stack Overflow had a job board...
#
#                                                 EntTeams           SOComm  \
# 8                    No, and I don't know what those are  Yes, definitely
# 10                   No, and I don't know what those are    Yes, somewhat
# 15     No, I've heard of them, but I am not part of a...    Yes, somewhat
# 50                   No, and I don't know what those are  Yes, definitely
# 65                   No, and I don't know what those are         Not sure
# ...                                                  ...              ...
# 77339  No, I've heard of them, but I am not part of a...    Yes, somewhat
# 79795                No, and I don't know what those are          Neutral
# 83862                No, and I don't know what those are  Yes, definitely
# 84299                No, and I don't know what those are    Yes, somewhat
# 86012                                                Yes    Yes, somewhat
#
#                                            WelcomeChange  \
# 8                  A lot more welcome now than last year
# 10              Somewhat less welcome now than last year
# 15               Just as welcome now as I felt last year
# 50               Just as welcome now as I felt last year
# 65                 A lot more welcome now than last year
# ...                                                  ...
# 77339  Not applicable - I did not use Stack Overflow ...
# 79795           Somewhat more welcome now than last year
# 83862            Just as welcome now as I felt last year
# 84299           Somewhat more welcome now than last year
# 86012  Not applicable - I did not use Stack Overflow ...
#
#                                             SONewContent   Age Gender Trans  \
# 8      Tech articles written by other developers;Indu...  24.0    Man    No
# 10     Tech articles written by other developers;Tech...   NaN   None  None
# 15     Tech articles written by other developers;Indu...  20.0    Man    No
# 50     Tech articles written by other developers;Tech...  23.0    Man    No
# 65                                                  None  21.0    Man    No
# ...                                                  ...   ...    ...   ...
# 77339  Tech articles written by other developers;Indu...   NaN   None  None
# 79795  Tech meetups or events in your area;Courses on...   NaN    Man    No
# 83862  Tech articles written by other developers;Indu...  24.0    Man    No
# 84299                                               None   NaN   None  None
# 86012  Industry news about technologies you're intere...  24.0    Man    No
#
#                      Sexuality    Ethnicity Dependents           SurveyLength  \
# 8      Straight / Heterosexual         None       None  Appropriate in length
# 10                        None         None        Yes               Too long
# 15                        None         None        Yes               Too long
# 50                        None  South Asian         No               Too long
# 65                        None         None        Yes  Appropriate in length
# ...                        ...          ...        ...                    ...
# 77339                     None         None       None                   None
# 79795  Straight / Heterosexual         None         No               Too long
# 83862  Straight / Heterosexual         None        Yes               Too long
# 84299                     None         None       None                   None
# 86012                     None  South Asian       None  Appropriate in length
#
#                        SurveyEase
# 8      Neither easy nor difficult
# 10                      Difficult
# 15     Neither easy nor difficult
# 50                           Easy
# 65     Neither easy nor difficult
# ...                           ...
# 77339                        None
# 79795                   Difficult
# 83862  Neither easy nor difficult
# 84299                        None
# 86012                        Easy
#
# [9061 rows x 84 columns]

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('postgresql://postgres:Klass535pg@localhost:5432/NewDb')

# %%
india_df.to_sql('sample_table', engine)
# Out:
# 229

# %%
india_df.to_sql('sample_table', engine, if_exists='replace')
# Out:
# 229

# %%
sql_df = pd.read_sql('sample_table', engine, index_col='Respondent')

# %%
sql_df
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 75103                                         None      Yes
# 76822                                         None       No
# 83862                                         None      Yes
# 84299                                         None      Yes
# 86012                                         None      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# 15                                                      Never
# 50                                 Once a month or more often
# 65                                                      Never
# ...                                                       ...
# 75103                                                   Never
# 76822       Less than once a month but more than once per ...
# 83862                              Once a month or more often
# 84299                                                   Never
# 86012                              Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# 65                                                       None
# ...                                                       ...
# 75103       OSS is, on average, of HIGHER quality than pro...
# 76822       OSS is, on average, of HIGHER quality than pro...
# 83862       OSS is, on average, of HIGHER quality than pro...
# 84299       The quality of OSS and closed source software ...
# 86012       OSS is, on average, of HIGHER quality than pro...
#
#                                     Employment Country         Student  \
# Respondent
# 8           Not employed, but looking for work   India            None
# 10                          Employed full-time   India              No
# 15          Not employed, but looking for work   India  Yes, full-time
# 50                          Employed full-time   India              No
# 65                          Employed full-time   India              No
# ...                                        ...     ...             ...
# 75103                       Employed full-time   India              No
# 76822                                     None   India            None
# 83862                       Employed full-time   India  Yes, full-time
# 84299                       Employed full-time   India  Yes, full-time
# 86012                       Employed full-time   India              No
#
#                                                       EdLevel  \
# Respondent
# 8                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 10                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 15          Secondary school (e.g. American high school, G...
# 50                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 65                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                       ...
# 75103                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 76822                      Professional degree (JD, MD, etc.)
# 83862                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 84299                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 86012             Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                                UndergradMajor  \
# Respondent
# 8           Computer science, computer engineering, or sof...
# 10                                                       None
# 15                                                       None
# 50          Another engineering discipline (ex. civil, ele...
# 65          Information systems, information technology, o...
# ...                                                       ...
# 75103       Computer science, computer engineering, or sof...
# 76822       A health science (ex. nursing, pharmacy, radio...
# 83862                                                    None
# 84299                           Web development or web design
# 86012       Another engineering discipline (ex. civil, ele...
#
#                                                      EduOther  \
# Respondent
# 8           Taught yourself a new language, framework, or ...
# 10                                                       None
# 15          Taken an online course in programming or softw...
# 50          Received on-the-job training in software devel...
# 65                                                       None
# ...                                                       ...
# 75103                                                    None
# 76822                                                    None
# 83862                             Participated in a hackathon
# 84299       Taken an online course in programming or softw...
# 86012       Taught yourself a new language, framework, or ...
#
#                              OrgSize  \
# Respondent
# 8                               None
# 10          10,000 or more employees
# 15                              None
# 50          10,000 or more employees
# 65                20 to 99 employees
# ...                              ...
# 75103       10,000 or more employees
# 76822                           None
# 83862                           None
# 84299           100 to 499 employees
# 86012           100 to 499 employees
#
#                                                       DevType YearsCode  \
# Respondent
# 8              Developer, back-end;Engineer, site reliability         8
# 10          Data or business analyst;Data scientist or mac...        12
# 15                                                    Student         3
# 50                      Developer, back-end;DevOps specialist         7
# 65                     Developer, front-end;Developer, mobile         2
# ...                                                       ...       ...
# 75103                 Developer, QA or test;DevOps specialist        10
# 76822                                                    None         3
# 83862                        Data or business analyst;Student         1
# 84299       Developer, back-end;Developer, front-end;Devel...        12
# 86012                            Academic researcher;Educator         5
#
#            Age1stCode      YearsCodePro              CareerSat  \
# Respondent
# 8                  16              None                   None
# 10                 20                10  Slightly dissatisfied
# 15                 13              None                   None
# 50                 15                 2     Slightly satisfied
# 65                 17                 2         Very satisfied
# ...               ...               ...                    ...
# 75103              20                10                   None
# 76822              42                 1                   None
# 83862              18  Less than 1 year                   None
# 84299              25                12                   None
# 86012              15              None                   None
#
#                            JobSat            MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 8                            None                None      None      None
# 10          Slightly dissatisfied  Somewhat confident       Yes       Yes
# 15                           None                None      None      None
# 50                 Very satisfied      Very confident  Not sure       Yes
# 65                 Very satisfied      Very confident        No  Not sure
# ...                           ...                 ...       ...       ...
# 75103                        None      Very confident       Yes       Yes
# 76822                        None                None      None      None
# 83862                        None      Very confident  Not sure       Yes
# 84299                        None                None      None      None
# 86012                        None  Somewhat confident        No  Not sure
#
#                                                       JobSeek  \
# Respondent
# 8                                                        None
# 10          I’m not actively looking, but I am open to new...
# 15          I’m not actively looking, but I am open to new...
# 50          I’m not actively looking, but I am open to new...
# 65          I’m not actively looking, but I am open to new...
# ...                                                       ...
# 75103                                                    None
# 76822                                                    None
# 83862                                                    None
# 84299                                                    None
# 86012                                                    None
#
#                     LastHireDate  \
# Respondent
# 8                           None
# 10                 3-4 years ago
# 15          I've never had a job
# 50                 1-2 years ago
# 65          Less than a year ago
# ...                          ...
# 75103                       None
# 76822                       None
# 83862                       None
# 84299                       None
# 86012                       None
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 8                                                        None     None
# 10                                                       None       No
# 15                                                       None     None
# 50          Write code by hand (e.g., on a whiteboard);Int...       No
# 65          Write any code;Solve a brain-teaser style puzz...       No
# ...                                                       ...      ...
# 75103                                                    None     None
# 76822                                                    None     None
# 83862                                                    None     None
# 84299                                                    None     None
# 86012                                                    None     None
#
#                                                    JobFactors  \
# Respondent
# 8                                                        None
# 10          Languages, frameworks, and other technologies ...
# 15          Industry that I'd be working in;Languages, fra...
# 50          Specific department or team I'd be working on;...
# 65          Languages, frameworks, and other technologies ...
# ...                                                       ...
# 75103                                                    None
# 76822                                                    None
# 83862                                                    None
# 84299                                                    None
# 86012                                                    None
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 8                                                        None           None
# 10                                                       None            INR
# 15          Something else changed (education, award, medi...           None
# 50                           I was preparing for a job search            INR
# 65           My job status changed (promotion, new job, etc.)            INR
# ...                                                       ...            ...
# 75103                                                    None           None
# 76822                                                    None           None
# 83862                                                    None           None
# 84299                                                    None           None
# 86012                                                    None           None
#
#             CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# Respondent
# 8                   None        NaN     None            NaN          NaN
# 10          Indian rupee   950000.0   Yearly        13293.0         70.0
# 15                  None        NaN     None            NaN          NaN
# 50          Indian rupee   400000.0   Yearly         5597.0          7.0
# 65          Indian rupee        NaN  Monthly            NaN         48.0
# ...                  ...        ...      ...            ...          ...
# 75103               None        NaN     None            NaN          NaN
# 76822               None        NaN     None            NaN          NaN
# 83862               None        NaN     None            NaN          NaN
# 84299               None        NaN     None            NaN          NaN
# 86012               None        NaN     None            NaN          NaN
#
#                                                      WorkPlan  \
# Respondent
# 8                                                        None
# 10          There's no schedule or spec; I work on what se...
# 15                                                       None
# 50          There is a schedule and/or spec (made by me or...
# 65          There's no schedule or spec; I work on what se...
# ...                                                       ...
# 75103                                                    None
# 76822                                                    None
# 83862                                                    None
# 84299                                                    None
# 86012                                                    None
#
#                             WorkChallenge                        WorkRemote  \
# Respondent
# 8                                    None                              None
# 10                                   None             A few days each month
# 15                                   None                              None
# 50          Meetings;Time spent commuting  Less than once per month / Never
# 65                                   None               About half the time
# ...                                   ...                               ...
# 75103                                None                              None
# 76822                                None                              None
# 83862                                None                              None
# 84299                                None                              None
# 86012                                None                              None
#
#                                                    WorkLoc             ImpSyn  \
# Respondent
# 8                                                     None               None
# 10                                                    Home  Far above average
# 15                                                    None               None
# 50          Other place, such as a coworking space or cafe            Average
# 65                                                  Office            Average
# ...                                                    ...                ...
# 75103                                                 None               None
# 76822                                                 None               None
# 83862                                                 None               None
# 84299                                                 None               None
# 86012                                                 None               None
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 8                                              None         NaN
# 10          Yes, because I see value in code review         4.0
# 15                                             None         NaN
# 50                                               No         NaN
# 65          Yes, because I see value in code review         NaN
# ...                                             ...         ...
# 75103                                          None         NaN
# 76822                                          None         NaN
# 83862                                          None         NaN
# 84299                                          None         NaN
# 86012                                          None         NaN
#
#                                                     UnitTests  \
# Respondent
# 8                                                        None
# 10                              Yes, it's part of our process
# 15                                                       None
# 50          Yes, it's not part of our process but the deve...
# 65          Yes, it's not part of our process but the deve...
# ...                                                       ...
# 75103                                                    None
# 76822                                                    None
# 83862                                                    None
# 84299                                                    None
# 86012                                                    None
#
#                                                   PurchaseHow  \
# Respondent
# 8                                                        None
# 10                                                       None
# 15                                                       None
# 50          The CTO, CIO, or other management purchase new...
# 65                                                   Not sure
# ...                                                       ...
# 75103                                                    None
# 76822                                                    None
# 83862                                                    None
# 84299                                                    None
# 86012                                                    None
#
#                              PurchaseWhat  \
# Respondent
# 8                                    None
# 10                                   None
# 15                                   None
# 50          I have little or no influence
# 65                                   None
# ...                                   ...
# 75103                                None
# 76822                                None
# 83862                                None
# 84299                                None
# 86012                                None
#
#                                            LanguageWorkedWith  \
# Respondent
# 8           Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 10                              C#;Go;JavaScript;Python;R;SQL
# 15          Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 50          Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 65                            Assembly;C;C++;C#;HTML/CSS;Java
# ...                                                       ...
# 75103                                                Java;VBA
# 76822       Assembly;C++;HTML/CSS;JavaScript;PHP;SQL;Other...
# 83862       Assembly;C;C++;HTML/CSS;Java;JavaScript;Object...
# 84299        HTML/CSS;Java;JavaScript;Python;Swift;TypeScript
# 86012           Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript
#
#                                        LanguageDesireNextYear  \
# Respondent
# 8           Bash/Shell/PowerShell;C;C++;Elixir;Erlang;Go;P...
# 10                       C#;Go;JavaScript;Kotlin;Python;R;SQL
# 15          Assembly;Bash/Shell/PowerShell;C;C++;C#;Go;HTM...
# 50                                 HTML/CSS;JavaScript;Python
# 65                                                     Kotlin
# ...                                                       ...
# 75103                                                  Python
# 76822       Assembly;C++;HTML/CSS;JavaScript;PHP;SQL;Other...
# 83862                                                    None
# 84299                                HTML/CSS;Java;JavaScript
# 86012                                              C++;Python
#
#                                            DatabaseWorkedWith  \
# Respondent
# 8           Cassandra;Elasticsearch;MongoDB;MySQL;Oracle;R...
# 10          Elasticsearch;MongoDB;Microsoft SQL Server;MyS...
# 15                                MariaDB;MySQL;Oracle;SQLite
# 50          Elasticsearch;Firebase;MariaDB;MongoDB;MySQL;O...
# 65                               Firebase;MySQL;Oracle;SQLite
# ...                                                       ...
# 75103                                                  Oracle
# 76822                                    MariaDB;MySQL;SQLite
# 83862                                                   MySQL
# 84299                                    MongoDB;Redis;SQLite
# 86012                                                   MySQL
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 8           Cassandra;DynamoDB;Elasticsearch;Firebase;Mong...
# 10                 Elasticsearch;MongoDB;Microsoft SQL Server
# 15          MariaDB;MongoDB;Microsoft SQL Server;MySQL;Ora...
# 50                        Firebase;PostgreSQL;Redis;Other(s):
# 65                                            Firebase;SQLite
# ...                                                       ...
# 75103                                                 MongoDB
# 76822                                           MariaDB;MySQL
# 83862                          DynamoDB;Elasticsearch;MongoDB
# 84299                                           MongoDB;Redis
# 86012                                                    None
#
#                                            PlatformWorkedWith  \
# Respondent
# 8                         AWS;Docker;Heroku;Linux;MacOS;Slack
# 10                                              Linux;Windows
# 15                                              Linux;Windows
# 50          Arduino;AWS;Heroku;Linux;MacOS;Raspberry Pi;Wo...
# 65                                                    Android
# ...                                                       ...
# 75103                                           Linux;Windows
# 76822       Android;Docker;Google Cloud Platform;iOS;Linux...
# 83862             Android;AWS;Google Cloud Platform;WordPress
# 84299                                                    None
# 86012                                               Other(s):
#
#                                        PlatformDesireNextYear  \
# Respondent
# 8           Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 10                         Android;Linux;Raspberry Pi;Windows
# 15          Android;Google Cloud Platform;iOS;Linux;MacOS;...
# 50          AWS;Docker;Heroku;Kubernetes;Linux;MacOS;WordP...
# 65                                                    Android
# ...                                                       ...
# 75103       Android;AWS;Docker;Google Cloud Platform;Kuber...
# 76822                                 Android;Linux;WordPress
# 83862                                     IBM Cloud or Watson
# 84299                                                    None
# 86012                                               Other(s):
#
#                                            WebFrameWorkedWith  \
# Respondent
# 8                               Express;Flask;React.js;Spring
# 10          Angular/Angular.js;ASP.NET;Django;Express;Flas...
# 15                                                       None
# 50                                Django;Express;Flask;jQuery
# 65                                                    ASP.NET
# ...                                                       ...
# 75103                                                    None
# 76822       Angular/Angular.js;Drupal;jQuery;Laravel;React...
# 83862                                                 Laravel
# 84299       Angular/Angular.js;Express;jQuery;React.js;Oth...
# 86012                                                    None
#
#                                        WebFrameDesireNextYear  \
# Respondent
# 8                        Django;Express;Flask;React.js;Vue.js
# 10          Angular/Angular.js;ASP.NET;Django;Express;Flas...
# 15          Angular/Angular.js;ASP.NET;Django;Drupal;jQuer...
# 50                       Express;Flask;jQuery;React.js;Vue.js
# 65                                                       None
# ...                                                       ...
# 75103                                                    None
# 76822                                          jQuery;Laravel
# 83862                       Angular/Angular.js;Laravel;Vue.js
# 84299                              Express;React.js;Other(s):
# 86012                                                    None
#
#                                   MiscTechWorkedWith  \
# Respondent
# 8                              Hadoop;Node.js;Pandas
# 10                 .NET;Node.js;Pandas;Torch/PyTorch
# 15                                              None
# 50                                           Node.js
# 65                                              None
# ...                                              ...
# 75103                                           None
# 76822       Apache Spark;Node.js;Pandas;React Native
# 83862                                           None
# 84299                                        Node.js
# 86012                                           None
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 8           Ansible;Apache Spark;Chef;Hadoop;Node.js;Panda...
# 10                      .NET;Node.js;TensorFlow;Torch/PyTorch
# 15          .NET;.NET Core;Node.js;TensorFlow;Unity 3D;Unr...
# 50                                                    Node.js
# 65                                                       None
# ...                                                       ...
# 75103                                                    None
# 76822                                    Apache Spark;Node.js
# 83862                                                 Node.js
# 84299                                                 Node.js
# 86012                                                    None
#
#                                                    DevEnviron        OpSys  \
# Respondent
# 8           Atom;IntelliJ;IPython / Jupyter;PyCharm;Visual...  Linux-based
# 10          Android Studio;Eclipse;IPython / Jupyter;Notep...      Windows
# 15                   Atom;NetBeans;Notepad++;Sublime Text;Vim  Linux-based
# 50                               Notepad++;Visual Studio Code        MacOS
# 65                                    Android Studio;IntelliJ  Linux-based
# ...                                                       ...          ...
# 75103                               Eclipse;Notepad++;PyCharm      Windows
# 76822       Android Studio;Notepad++;PHPStorm;Sublime Text...  Linux-based
# 83862       Android Studio;Atom;IntelliJ;Komodo;NetBeans;N...      Windows
# 84299             IntelliJ;Notepad++;Visual Studio Code;Xcode      Windows
# 86012                                               Notepad++  Linux-based
#
#                                                    Containers BlockchainOrg  \
# Respondent
# 8           Development;Testing;Production;Outside of work...          None
# 10                                                       None    Not at all
# 15                                                Development          None
# 50                                                    Testing    Not at all
# 65                                                       None          None
# ...                                                       ...           ...
# 75103                                                 Testing          None
# 76822                                                 Testing          None
# 83862                                 I do not use containers          None
# 84299                                                    None          None
# 86012                                 I do not use containers          None
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 8           Useful across many domains and could change ma...        Yes
# 10          Useful for immutable record keeping outside of...         No
# 15                                                       None        Yes
# 50          Useful for immutable record keeping outside of...        Yes
# 65                                                       None        Yes
# ...                                                       ...        ...
# 75103                                                    None        Yes
# 76822                                                    None        Yes
# 83862       Useful across many domains and could change ma...         No
# 84299                                                    None        Yes
# 86012                                                    None         No
#
#                                             ITperson  OffOn  \
# Respondent
# 8                                               SIGH    Yes
# 10                                               Yes    Yes
# 15                                               Yes  What?
# 50                                          Also Yes  What?
# 65                                               Yes  What?
# ...                                              ...    ...
# 75103                                            Yes     No
# 76822                                            Yes     No
# 83862                                            Yes  What?
# 84299       Fortunately, someone else has that title  What?
# 86012                                       Also Yes  What?
#
#                          SocialMedia              Extraversion   ScreenName  \
# Respondent
# 8                            YouTube  In real life (in person)       Handle
# 10                           YouTube                   Neither  Screen Name
# 15                           YouTube  In real life (in person)         None
# 50                           YouTube  In real life (in person)     Username
# 65                          WhatsApp  In real life (in person)         None
# ...                              ...                       ...          ...
# 75103                       LinkedIn                    Online       UserID
# 76822                       WhatsApp                   Neither        Login
# 83862                        Twitter                    Online       UserID
# 84299                       LinkedIn                      None         None
# 86012       I don't use social media                    Online     Username
#
#            SOVisit1st                      SOVisitFreq  \
# Respondent
# 8                2012             A few times per week
# 10               None           Multiple times per day
# 15               2018            Daily or almost daily
# 50               2012            Daily or almost daily
# 65               2017           Multiple times per day
# ...               ...                              ...
# 75103            2008           Multiple times per day
# 76822            None             A few times per week
# 83862            2012  A few times per month or weekly
# 84299            2011  A few times per month or weekly
# 86012            2014  A few times per month or weekly
#
#                                                     SOVisitTo  \
# Respondent
# 8           Find answers to specific questions;Learn how t...
# 10          Find answers to specific questions;Get a sense...
# 15          Find answers to specific questions;Learn how t...
# 50          Find answers to specific questions;Learn how t...
# 65                         Find answers to specific questions
# ...                                                       ...
# 75103       Find answers to specific questions;Learn how t...
# 76822       Find answers to specific questions;Get a sense...
# 83862       Find answers to specific questions;Learn how t...
# 84299       Find answers to specific questions;Contribute ...
# 86012                      Find answers to specific questions
#
#                            SOFindAnswer                         SOTimeSaved  \
# Respondent
# 8               Less than once per week  Stack Overflow was slightly faster
# 10                   3-5 times per week            They were about the same
# 15          More than 10 times per week            They were about the same
# 50                   3-5 times per week  Stack Overflow was slightly faster
# 65          More than 10 times per week  Stack Overflow was slightly faster
# ...                                 ...                                 ...
# 75103       More than 10 times per week      Stack Overflow was much faster
# 76822                1-2 times per week      Stack Overflow was much faster
# 83862           Less than once per week      Stack Overflow was much faster
# 84299           Less than once per week      Stack Overflow was much faster
# 86012           Less than once per week      Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount  \
# Respondent
# 8           11-30 minutes       Yes
# 10                   None       Yes
# 15                   None       Yes
# 50          11-30 minutes       Yes
# 65          11-30 minutes       Yes
# ...                   ...       ...
# 75103       31-60 minutes       Yes
# 76822       11-30 minutes        No
# 83862        0-10 minutes       Yes
# 84299         60+ minutes       Yes
# 86012       11-30 minutes       Yes
#
#                                                    SOPartFreq  \
# Respondent
# 8                         Less than once per month or monthly
# 10                            A few times per month or weekly
# 15                        Less than once per month or monthly
# 50                        Less than once per month or monthly
# 65                                       A few times per week
# ...                                                       ...
# 75103                                    A few times per week
# 76822                                                    None
# 83862       I have never participated in Q&A on Stack Over...
# 84299                     Less than once per month or monthly
# 86012                                                    None
#
#                                                        SOJobs  \
# Respondent
# 8                                                         Yes
# 10                                                        Yes
# 15                                                        Yes
# 50          No, I knew that Stack Overflow had a job board...
# 65          No, I knew that Stack Overflow had a job board...
# ...                                                       ...
# 75103       No, I knew that Stack Overflow had a job board...
# 76822       No, I didn't know that Stack Overflow had a jo...
# 83862                                                     Yes
# 84299                                                     Yes
# 86012       No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 8                         No, and I don't know what those are
# 10                        No, and I don't know what those are
# 15          No, I've heard of them, but I am not part of a...
# 50                        No, and I don't know what those are
# 65                        No, and I don't know what those are
# ...                                                       ...
# 75103                     No, and I don't know what those are
# 76822                     No, and I don't know what those are
# 83862                     No, and I don't know what those are
# 84299                     No, and I don't know what those are
# 86012                                                     Yes
#
#                      SOComm  \
# Respondent
# 8           Yes, definitely
# 10            Yes, somewhat
# 15            Yes, somewhat
# 50          Yes, definitely
# 65                 Not sure
# ...                     ...
# 75103       Yes, definitely
# 76822         Yes, somewhat
# 83862       Yes, definitely
# 84299         Yes, somewhat
# 86012         Yes, somewhat
#
#                                                 WelcomeChange  \
# Respondent
# 8                       A lot more welcome now than last year
# 10                   Somewhat less welcome now than last year
# 15                    Just as welcome now as I felt last year
# 50                    Just as welcome now as I felt last year
# 65                      A lot more welcome now than last year
# ...                                                       ...
# 75103                   A lot more welcome now than last year
# 76822                 Just as welcome now as I felt last year
# 83862                 Just as welcome now as I felt last year
# 84299                Somewhat more welcome now than last year
# 86012       Not applicable - I did not use Stack Overflow ...
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 8           Tech articles written by other developers;Indu...  24.0    Man
# 10          Tech articles written by other developers;Tech...   NaN   None
# 15          Tech articles written by other developers;Indu...  20.0    Man
# 50          Tech articles written by other developers;Tech...  23.0    Man
# 65                                                       None  21.0    Man
# ...                                                       ...   ...    ...
# 75103       Tech articles written by other developers;Indu...   NaN   None
# 76822                                                    None   NaN    Man
# 83862       Tech articles written by other developers;Indu...  24.0    Man
# 84299                                                    None   NaN   None
# 86012       Industry news about technologies you're intere...  24.0    Man
#
#            Trans                Sexuality    Ethnicity Dependents  \
# Respondent
# 8             No  Straight / Heterosexual         None       None
# 10          None                     None         None        Yes
# 15            No                     None         None        Yes
# 50            No                     None  South Asian         No
# 65            No                     None         None        Yes
# ...          ...                      ...          ...        ...
# 75103       None                     None         None         No
# 76822         No  Straight / Heterosexual  South Asian        Yes
# 83862         No  Straight / Heterosexual         None        Yes
# 84299       None                     None         None       None
# 86012         No                     None  South Asian       None
#
#                      SurveyLength                  SurveyEase
# Respondent
# 8           Appropriate in length  Neither easy nor difficult
# 10                       Too long                   Difficult
# 15                       Too long  Neither easy nor difficult
# 50                       Too long                        Easy
# 65          Appropriate in length  Neither easy nor difficult
# ...                           ...                         ...
# 75103                    Too long                        Easy
# 76822                    Too long                        Easy
# 83862                    Too long  Neither easy nor difficult
# 84299                        None                        None
# 86012       Appropriate in length                        Easy
#
# [9061 rows x 84 columns]

# %%
sql_df = pd.read_sql_query('SELECT * FROM sample_table', engine, index_col='Respondent')

# %%
sql_df
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 75103                                         None      Yes
# 76822                                         None       No
# 83862                                         None      Yes
# 84299                                         None      Yes
# 86012                                         None      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# 15                                                      Never
# 50                                 Once a month or more often
# 65                                                      Never
# ...                                                       ...
# 75103                                                   Never
# 76822       Less than once a month but more than once per ...
# 83862                              Once a month or more often
# 84299                                                   Never
# 86012                              Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# 65                                                       None
# ...                                                       ...
# 75103       OSS is, on average, of HIGHER quality than pro...
# 76822       OSS is, on average, of HIGHER quality than pro...
# 83862       OSS is, on average, of HIGHER quality than pro...
# 84299       The quality of OSS and closed source software ...
# 86012       OSS is, on average, of HIGHER quality than pro...
#
#                                     Employment Country         Student  \
# Respondent
# 8           Not employed, but looking for work   India            None
# 10                          Employed full-time   India              No
# 15          Not employed, but looking for work   India  Yes, full-time
# 50                          Employed full-time   India              No
# 65                          Employed full-time   India              No
# ...                                        ...     ...             ...
# 75103                       Employed full-time   India              No
# 76822                                     None   India            None
# 83862                       Employed full-time   India  Yes, full-time
# 84299                       Employed full-time   India  Yes, full-time
# 86012                       Employed full-time   India              No
#
#                                                       EdLevel  \
# Respondent
# 8                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 10                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 15          Secondary school (e.g. American high school, G...
# 50                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 65                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                       ...
# 75103                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 76822                      Professional degree (JD, MD, etc.)
# 83862                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 84299                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 86012             Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                                UndergradMajor  \
# Respondent
# 8           Computer science, computer engineering, or sof...
# 10                                                       None
# 15                                                       None
# 50          Another engineering discipline (ex. civil, ele...
# 65          Information systems, information technology, o...
# ...                                                       ...
# 75103       Computer science, computer engineering, or sof...
# 76822       A health science (ex. nursing, pharmacy, radio...
# 83862                                                    None
# 84299                           Web development or web design
# 86012       Another engineering discipline (ex. civil, ele...
#
#                                                      EduOther  \
# Respondent
# 8           Taught yourself a new language, framework, or ...
# 10                                                       None
# 15          Taken an online course in programming or softw...
# 50          Received on-the-job training in software devel...
# 65                                                       None
# ...                                                       ...
# 75103                                                    None
# 76822                                                    None
# 83862                             Participated in a hackathon
# 84299       Taken an online course in programming or softw...
# 86012       Taught yourself a new language, framework, or ...
#
#                              OrgSize  \
# Respondent
# 8                               None
# 10          10,000 or more employees
# 15                              None
# 50          10,000 or more employees
# 65                20 to 99 employees
# ...                              ...
# 75103       10,000 or more employees
# 76822                           None
# 83862                           None
# 84299           100 to 499 employees
# 86012           100 to 499 employees
#
#                                                       DevType YearsCode  \
# Respondent
# 8              Developer, back-end;Engineer, site reliability         8
# 10          Data or business analyst;Data scientist or mac...        12
# 15                                                    Student         3
# 50                      Developer, back-end;DevOps specialist         7
# 65                     Developer, front-end;Developer, mobile         2
# ...                                                       ...       ...
# 75103                 Developer, QA or test;DevOps specialist        10
# 76822                                                    None         3
# 83862                        Data or business analyst;Student         1
# 84299       Developer, back-end;Developer, front-end;Devel...        12
# 86012                            Academic researcher;Educator         5
#
#            Age1stCode      YearsCodePro              CareerSat  \
# Respondent
# 8                  16              None                   None
# 10                 20                10  Slightly dissatisfied
# 15                 13              None                   None
# 50                 15                 2     Slightly satisfied
# 65                 17                 2         Very satisfied
# ...               ...               ...                    ...
# 75103              20                10                   None
# 76822              42                 1                   None
# 83862              18  Less than 1 year                   None
# 84299              25                12                   None
# 86012              15              None                   None
#
#                            JobSat            MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 8                            None                None      None      None
# 10          Slightly dissatisfied  Somewhat confident       Yes       Yes
# 15                           None                None      None      None
# 50                 Very satisfied      Very confident  Not sure       Yes
# 65                 Very satisfied      Very confident        No  Not sure
# ...                           ...                 ...       ...       ...
# 75103                        None      Very confident       Yes       Yes
# 76822                        None                None      None      None
# 83862                        None      Very confident  Not sure       Yes
# 84299                        None                None      None      None
# 86012                        None  Somewhat confident        No  Not sure
#
#                                                       JobSeek  \
# Respondent
# 8                                                        None
# 10          I’m not actively looking, but I am open to new...
# 15          I’m not actively looking, but I am open to new...
# 50          I’m not actively looking, but I am open to new...
# 65          I’m not actively looking, but I am open to new...
# ...                                                       ...
# 75103                                                    None
# 76822                                                    None
# 83862                                                    None
# 84299                                                    None
# 86012                                                    None
#
#                     LastHireDate  \
# Respondent
# 8                           None
# 10                 3-4 years ago
# 15          I've never had a job
# 50                 1-2 years ago
# 65          Less than a year ago
# ...                          ...
# 75103                       None
# 76822                       None
# 83862                       None
# 84299                       None
# 86012                       None
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 8                                                        None     None
# 10                                                       None       No
# 15                                                       None     None
# 50          Write code by hand (e.g., on a whiteboard);Int...       No
# 65          Write any code;Solve a brain-teaser style puzz...       No
# ...                                                       ...      ...
# 75103                                                    None     None
# 76822                                                    None     None
# 83862                                                    None     None
# 84299                                                    None     None
# 86012                                                    None     None
#
#                                                    JobFactors  \
# Respondent
# 8                                                        None
# 10          Languages, frameworks, and other technologies ...
# 15          Industry that I'd be working in;Languages, fra...
# 50          Specific department or team I'd be working on;...
# 65          Languages, frameworks, and other technologies ...
# ...                                                       ...
# 75103                                                    None
# 76822                                                    None
# 83862                                                    None
# 84299                                                    None
# 86012                                                    None
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 8                                                        None           None
# 10                                                       None            INR
# 15          Something else changed (education, award, medi...           None
# 50                           I was preparing for a job search            INR
# 65           My job status changed (promotion, new job, etc.)            INR
# ...                                                       ...            ...
# 75103                                                    None           None
# 76822                                                    None           None
# 83862                                                    None           None
# 84299                                                    None           None
# 86012                                                    None           None
#
#             CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# Respondent
# 8                   None        NaN     None            NaN          NaN
# 10          Indian rupee   950000.0   Yearly        13293.0         70.0
# 15                  None        NaN     None            NaN          NaN
# 50          Indian rupee   400000.0   Yearly         5597.0          7.0
# 65          Indian rupee        NaN  Monthly            NaN         48.0
# ...                  ...        ...      ...            ...          ...
# 75103               None        NaN     None            NaN          NaN
# 76822               None        NaN     None            NaN          NaN
# 83862               None        NaN     None            NaN          NaN
# 84299               None        NaN     None            NaN          NaN
# 86012               None        NaN     None            NaN          NaN
#
#                                                      WorkPlan  \
# Respondent
# 8                                                        None
# 10          There's no schedule or spec; I work on what se...
# 15                                                       None
# 50          There is a schedule and/or spec (made by me or...
# 65          There's no schedule or spec; I work on what se...
# ...                                                       ...
# 75103                                                    None
# 76822                                                    None
# 83862                                                    None
# 84299                                                    None
# 86012                                                    None
#
#                             WorkChallenge                        WorkRemote  \
# Respondent
# 8                                    None                              None
# 10                                   None             A few days each month
# 15                                   None                              None
# 50          Meetings;Time spent commuting  Less than once per month / Never
# 65                                   None               About half the time
# ...                                   ...                               ...
# 75103                                None                              None
# 76822                                None                              None
# 83862                                None                              None
# 84299                                None                              None
# 86012                                None                              None
#
#                                                    WorkLoc             ImpSyn  \
# Respondent
# 8                                                     None               None
# 10                                                    Home  Far above average
# 15                                                    None               None
# 50          Other place, such as a coworking space or cafe            Average
# 65                                                  Office            Average
# ...                                                    ...                ...
# 75103                                                 None               None
# 76822                                                 None               None
# 83862                                                 None               None
# 84299                                                 None               None
# 86012                                                 None               None
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 8                                              None         NaN
# 10          Yes, because I see value in code review         4.0
# 15                                             None         NaN
# 50                                               No         NaN
# 65          Yes, because I see value in code review         NaN
# ...                                             ...         ...
# 75103                                          None         NaN
# 76822                                          None         NaN
# 83862                                          None         NaN
# 84299                                          None         NaN
# 86012                                          None         NaN
#
#                                                     UnitTests  \
# Respondent
# 8                                                        None
# 10                              Yes, it's part of our process
# 15                                                       None
# 50          Yes, it's not part of our process but the deve...
# 65          Yes, it's not part of our process but the deve...
# ...                                                       ...
# 75103                                                    None
# 76822                                                    None
# 83862                                                    None
# 84299                                                    None
# 86012                                                    None
#
#                                                   PurchaseHow  \
# Respondent
# 8                                                        None
# 10                                                       None
# 15                                                       None
# 50          The CTO, CIO, or other management purchase new...
# 65                                                   Not sure
# ...                                                       ...
# 75103                                                    None
# 76822                                                    None
# 83862                                                    None
# 84299                                                    None
# 86012                                                    None
#
#                              PurchaseWhat  \
# Respondent
# 8                                    None
# 10                                   None
# 15                                   None
# 50          I have little or no influence
# 65                                   None
# ...                                   ...
# 75103                                None
# 76822                                None
# 83862                                None
# 84299                                None
# 86012                                None
#
#                                            LanguageWorkedWith  \
# Respondent
# 8           Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 10                              C#;Go;JavaScript;Python;R;SQL
# 15          Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 50          Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 65                            Assembly;C;C++;C#;HTML/CSS;Java
# ...                                                       ...
# 75103                                                Java;VBA
# 76822       Assembly;C++;HTML/CSS;JavaScript;PHP;SQL;Other...
# 83862       Assembly;C;C++;HTML/CSS;Java;JavaScript;Object...
# 84299        HTML/CSS;Java;JavaScript;Python;Swift;TypeScript
# 86012           Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript
#
#                                        LanguageDesireNextYear  \
# Respondent
# 8           Bash/Shell/PowerShell;C;C++;Elixir;Erlang;Go;P...
# 10                       C#;Go;JavaScript;Kotlin;Python;R;SQL
# 15          Assembly;Bash/Shell/PowerShell;C;C++;C#;Go;HTM...
# 50                                 HTML/CSS;JavaScript;Python
# 65                                                     Kotlin
# ...                                                       ...
# 75103                                                  Python
# 76822       Assembly;C++;HTML/CSS;JavaScript;PHP;SQL;Other...
# 83862                                                    None
# 84299                                HTML/CSS;Java;JavaScript
# 86012                                              C++;Python
#
#                                            DatabaseWorkedWith  \
# Respondent
# 8           Cassandra;Elasticsearch;MongoDB;MySQL;Oracle;R...
# 10          Elasticsearch;MongoDB;Microsoft SQL Server;MyS...
# 15                                MariaDB;MySQL;Oracle;SQLite
# 50          Elasticsearch;Firebase;MariaDB;MongoDB;MySQL;O...
# 65                               Firebase;MySQL;Oracle;SQLite
# ...                                                       ...
# 75103                                                  Oracle
# 76822                                    MariaDB;MySQL;SQLite
# 83862                                                   MySQL
# 84299                                    MongoDB;Redis;SQLite
# 86012                                                   MySQL
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 8           Cassandra;DynamoDB;Elasticsearch;Firebase;Mong...
# 10                 Elasticsearch;MongoDB;Microsoft SQL Server
# 15          MariaDB;MongoDB;Microsoft SQL Server;MySQL;Ora...
# 50                        Firebase;PostgreSQL;Redis;Other(s):
# 65                                            Firebase;SQLite
# ...                                                       ...
# 75103                                                 MongoDB
# 76822                                           MariaDB;MySQL
# 83862                          DynamoDB;Elasticsearch;MongoDB
# 84299                                           MongoDB;Redis
# 86012                                                    None
#
#                                            PlatformWorkedWith  \
# Respondent
# 8                         AWS;Docker;Heroku;Linux;MacOS;Slack
# 10                                              Linux;Windows
# 15                                              Linux;Windows
# 50          Arduino;AWS;Heroku;Linux;MacOS;Raspberry Pi;Wo...
# 65                                                    Android
# ...                                                       ...
# 75103                                           Linux;Windows
# 76822       Android;Docker;Google Cloud Platform;iOS;Linux...
# 83862             Android;AWS;Google Cloud Platform;WordPress
# 84299                                                    None
# 86012                                               Other(s):
#
#                                        PlatformDesireNextYear  \
# Respondent
# 8           Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 10                         Android;Linux;Raspberry Pi;Windows
# 15          Android;Google Cloud Platform;iOS;Linux;MacOS;...
# 50          AWS;Docker;Heroku;Kubernetes;Linux;MacOS;WordP...
# 65                                                    Android
# ...                                                       ...
# 75103       Android;AWS;Docker;Google Cloud Platform;Kuber...
# 76822                                 Android;Linux;WordPress
# 83862                                     IBM Cloud or Watson
# 84299                                                    None
# 86012                                               Other(s):
#
#                                            WebFrameWorkedWith  \
# Respondent
# 8                               Express;Flask;React.js;Spring
# 10          Angular/Angular.js;ASP.NET;Django;Express;Flas...
# 15                                                       None
# 50                                Django;Express;Flask;jQuery
# 65                                                    ASP.NET
# ...                                                       ...
# 75103                                                    None
# 76822       Angular/Angular.js;Drupal;jQuery;Laravel;React...
# 83862                                                 Laravel
# 84299       Angular/Angular.js;Express;jQuery;React.js;Oth...
# 86012                                                    None
#
#                                        WebFrameDesireNextYear  \
# Respondent
# 8                        Django;Express;Flask;React.js;Vue.js
# 10          Angular/Angular.js;ASP.NET;Django;Express;Flas...
# 15          Angular/Angular.js;ASP.NET;Django;Drupal;jQuer...
# 50                       Express;Flask;jQuery;React.js;Vue.js
# 65                                                       None
# ...                                                       ...
# 75103                                                    None
# 76822                                          jQuery;Laravel
# 83862                       Angular/Angular.js;Laravel;Vue.js
# 84299                              Express;React.js;Other(s):
# 86012                                                    None
#
#                                   MiscTechWorkedWith  \
# Respondent
# 8                              Hadoop;Node.js;Pandas
# 10                 .NET;Node.js;Pandas;Torch/PyTorch
# 15                                              None
# 50                                           Node.js
# 65                                              None
# ...                                              ...
# 75103                                           None
# 76822       Apache Spark;Node.js;Pandas;React Native
# 83862                                           None
# 84299                                        Node.js
# 86012                                           None
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 8           Ansible;Apache Spark;Chef;Hadoop;Node.js;Panda...
# 10                      .NET;Node.js;TensorFlow;Torch/PyTorch
# 15          .NET;.NET Core;Node.js;TensorFlow;Unity 3D;Unr...
# 50                                                    Node.js
# 65                                                       None
# ...                                                       ...
# 75103                                                    None
# 76822                                    Apache Spark;Node.js
# 83862                                                 Node.js
# 84299                                                 Node.js
# 86012                                                    None
#
#                                                    DevEnviron        OpSys  \
# Respondent
# 8           Atom;IntelliJ;IPython / Jupyter;PyCharm;Visual...  Linux-based
# 10          Android Studio;Eclipse;IPython / Jupyter;Notep...      Windows
# 15                   Atom;NetBeans;Notepad++;Sublime Text;Vim  Linux-based
# 50                               Notepad++;Visual Studio Code        MacOS
# 65                                    Android Studio;IntelliJ  Linux-based
# ...                                                       ...          ...
# 75103                               Eclipse;Notepad++;PyCharm      Windows
# 76822       Android Studio;Notepad++;PHPStorm;Sublime Text...  Linux-based
# 83862       Android Studio;Atom;IntelliJ;Komodo;NetBeans;N...      Windows
# 84299             IntelliJ;Notepad++;Visual Studio Code;Xcode      Windows
# 86012                                               Notepad++  Linux-based
#
#                                                    Containers BlockchainOrg  \
# Respondent
# 8           Development;Testing;Production;Outside of work...          None
# 10                                                       None    Not at all
# 15                                                Development          None
# 50                                                    Testing    Not at all
# 65                                                       None          None
# ...                                                       ...           ...
# 75103                                                 Testing          None
# 76822                                                 Testing          None
# 83862                                 I do not use containers          None
# 84299                                                    None          None
# 86012                                 I do not use containers          None
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 8           Useful across many domains and could change ma...        Yes
# 10          Useful for immutable record keeping outside of...         No
# 15                                                       None        Yes
# 50          Useful for immutable record keeping outside of...        Yes
# 65                                                       None        Yes
# ...                                                       ...        ...
# 75103                                                    None        Yes
# 76822                                                    None        Yes
# 83862       Useful across many domains and could change ma...         No
# 84299                                                    None        Yes
# 86012                                                    None         No
#
#                                             ITperson  OffOn  \
# Respondent
# 8                                               SIGH    Yes
# 10                                               Yes    Yes
# 15                                               Yes  What?
# 50                                          Also Yes  What?
# 65                                               Yes  What?
# ...                                              ...    ...
# 75103                                            Yes     No
# 76822                                            Yes     No
# 83862                                            Yes  What?
# 84299       Fortunately, someone else has that title  What?
# 86012                                       Also Yes  What?
#
#                          SocialMedia              Extraversion   ScreenName  \
# Respondent
# 8                            YouTube  In real life (in person)       Handle
# 10                           YouTube                   Neither  Screen Name
# 15                           YouTube  In real life (in person)         None
# 50                           YouTube  In real life (in person)     Username
# 65                          WhatsApp  In real life (in person)         None
# ...                              ...                       ...          ...
# 75103                       LinkedIn                    Online       UserID
# 76822                       WhatsApp                   Neither        Login
# 83862                        Twitter                    Online       UserID
# 84299                       LinkedIn                      None         None
# 86012       I don't use social media                    Online     Username
#
#            SOVisit1st                      SOVisitFreq  \
# Respondent
# 8                2012             A few times per week
# 10               None           Multiple times per day
# 15               2018            Daily or almost daily
# 50               2012            Daily or almost daily
# 65               2017           Multiple times per day
# ...               ...                              ...
# 75103            2008           Multiple times per day
# 76822            None             A few times per week
# 83862            2012  A few times per month or weekly
# 84299            2011  A few times per month or weekly
# 86012            2014  A few times per month or weekly
#
#                                                     SOVisitTo  \
# Respondent
# 8           Find answers to specific questions;Learn how t...
# 10          Find answers to specific questions;Get a sense...
# 15          Find answers to specific questions;Learn how t...
# 50          Find answers to specific questions;Learn how t...
# 65                         Find answers to specific questions
# ...                                                       ...
# 75103       Find answers to specific questions;Learn how t...
# 76822       Find answers to specific questions;Get a sense...
# 83862       Find answers to specific questions;Learn how t...
# 84299       Find answers to specific questions;Contribute ...
# 86012                      Find answers to specific questions
#
#                            SOFindAnswer                         SOTimeSaved  \
# Respondent
# 8               Less than once per week  Stack Overflow was slightly faster
# 10                   3-5 times per week            They were about the same
# 15          More than 10 times per week            They were about the same
# 50                   3-5 times per week  Stack Overflow was slightly faster
# 65          More than 10 times per week  Stack Overflow was slightly faster
# ...                                 ...                                 ...
# 75103       More than 10 times per week      Stack Overflow was much faster
# 76822                1-2 times per week      Stack Overflow was much faster
# 83862           Less than once per week      Stack Overflow was much faster
# 84299           Less than once per week      Stack Overflow was much faster
# 86012           Less than once per week      Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount  \
# Respondent
# 8           11-30 minutes       Yes
# 10                   None       Yes
# 15                   None       Yes
# 50          11-30 minutes       Yes
# 65          11-30 minutes       Yes
# ...                   ...       ...
# 75103       31-60 minutes       Yes
# 76822       11-30 minutes        No
# 83862        0-10 minutes       Yes
# 84299         60+ minutes       Yes
# 86012       11-30 minutes       Yes
#
#                                                    SOPartFreq  \
# Respondent
# 8                         Less than once per month or monthly
# 10                            A few times per month or weekly
# 15                        Less than once per month or monthly
# 50                        Less than once per month or monthly
# 65                                       A few times per week
# ...                                                       ...
# 75103                                    A few times per week
# 76822                                                    None
# 83862       I have never participated in Q&A on Stack Over...
# 84299                     Less than once per month or monthly
# 86012                                                    None
#
#                                                        SOJobs  \
# Respondent
# 8                                                         Yes
# 10                                                        Yes
# 15                                                        Yes
# 50          No, I knew that Stack Overflow had a job board...
# 65          No, I knew that Stack Overflow had a job board...
# ...                                                       ...
# 75103       No, I knew that Stack Overflow had a job board...
# 76822       No, I didn't know that Stack Overflow had a jo...
# 83862                                                     Yes
# 84299                                                     Yes
# 86012       No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 8                         No, and I don't know what those are
# 10                        No, and I don't know what those are
# 15          No, I've heard of them, but I am not part of a...
# 50                        No, and I don't know what those are
# 65                        No, and I don't know what those are
# ...                                                       ...
# 75103                     No, and I don't know what those are
# 76822                     No, and I don't know what those are
# 83862                     No, and I don't know what those are
# 84299                     No, and I don't know what those are
# 86012                                                     Yes
#
#                      SOComm  \
# Respondent
# 8           Yes, definitely
# 10            Yes, somewhat
# 15            Yes, somewhat
# 50          Yes, definitely
# 65                 Not sure
# ...                     ...
# 75103       Yes, definitely
# 76822         Yes, somewhat
# 83862       Yes, definitely
# 84299         Yes, somewhat
# 86012         Yes, somewhat
#
#                                                 WelcomeChange  \
# Respondent
# 8                       A lot more welcome now than last year
# 10                   Somewhat less welcome now than last year
# 15                    Just as welcome now as I felt last year
# 50                    Just as welcome now as I felt last year
# 65                      A lot more welcome now than last year
# ...                                                       ...
# 75103                   A lot more welcome now than last year
# 76822                 Just as welcome now as I felt last year
# 83862                 Just as welcome now as I felt last year
# 84299                Somewhat more welcome now than last year
# 86012       Not applicable - I did not use Stack Overflow ...
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 8           Tech articles written by other developers;Indu...  24.0    Man
# 10          Tech articles written by other developers;Tech...   NaN   None
# 15          Tech articles written by other developers;Indu...  20.0    Man
# 50          Tech articles written by other developers;Tech...  23.0    Man
# 65                                                       None  21.0    Man
# ...                                                       ...   ...    ...
# 75103       Tech articles written by other developers;Indu...   NaN   None
# 76822                                                    None   NaN    Man
# 83862       Tech articles written by other developers;Indu...  24.0    Man
# 84299                                                    None   NaN   None
# 86012       Industry news about technologies you're intere...  24.0    Man
#
#            Trans                Sexuality    Ethnicity Dependents  \
# Respondent
# 8             No  Straight / Heterosexual         None       None
# 10          None                     None         None        Yes
# 15            No                     None         None        Yes
# 50            No                     None  South Asian         No
# 65            No                     None         None        Yes
# ...          ...                      ...          ...        ...
# 75103       None                     None         None         No
# 76822         No  Straight / Heterosexual  South Asian        Yes
# 83862         No  Straight / Heterosexual         None        Yes
# 84299       None                     None         None       None
# 86012         No                     None  South Asian       None
#
#                      SurveyLength                  SurveyEase
# Respondent
# 8           Appropriate in length  Neither easy nor difficult
# 10                       Too long                   Difficult
# 15                       Too long  Neither easy nor difficult
# 50                       Too long                        Easy
# 65          Appropriate in length  Neither easy nor difficult
# ...                           ...                         ...
# 75103                    Too long                        Easy
# 76822                    Too long                        Easy
# 83862                    Too long  Neither easy nor difficult
# 84299                        None                        None
# 86012       Appropriate in length                        Easy
#
# [9061 rows x 84 columns]

# %%
posts_df = pd.read_json('https://github.com/CoreyMSchafer/code_snippets/blob/master/Python/Flask_Blog/snippets/config.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 posts_df = pd.read_json('https://github.com/CoreyMSchafer/code_snippets/blob/master/Python/Flask_Blog/snippets/config.json')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\json\_json.py:804, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     802     return json_reader
#     803 else:
# --> 804     return json_reader.read()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\json\_json.py:1014, in JsonReader.read(self)
#    1012         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1013 else:
# -> 1014     obj = self._get_object_parser(self.data)
#    1015 if self.dtype_backend is not lib.no_default:
#    1016     return obj.convert_dtypes(
#    1017         infer_objects=False, dtype_backend=self.dtype_backend
#    1018     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\json\_json.py:1040, in JsonReader._get_object_parser(self, json)
#    1038 obj = None
#    1039 if typ == "frame":
# -> 1040     obj = FrameParser(json, **kwargs).parse()
#    1042 if typ == "series" or obj is None:
#    1043     if not isinstance(dtype, bool):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\json\_json.py:1173, in Parser.parse(self)
#    1172 def parse(self):
# -> 1173     self._parse()
#    1175     if self.obj is None:
#    1176         return None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\json\_json.py:1366, in FrameParser._parse(self)
#    1362 orient = self.orient
#    1364 if orient == "columns":
#    1365     self.obj = DataFrame(
# -> 1366         ujson_loads(json, precise_float=self.precise_float), dtype=None
#    1367     )
#    1368 elif orient == "split":
#    1369     decoded = {
#    1370         str(k): v
#    1371         for k, v in ujson_loads(json, precise_float=self.precise_float).items()
#    1372     }
#
# ValueError: Expected object or value
